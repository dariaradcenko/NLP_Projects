# %% [markdown]
# # Load Corpus

# %%
## Import the necessary libraries
import nltk
import string
from nltk.util import ngrams
from nltk.probability import FreqDist
from collections import defaultdict
import re
from nltk.corpus import reuters
from nltk.tokenize import word_tokenize

# %%
# Ensure the reuters corpus is downloaded
nltk.download('reuters')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package reuters to
# [nltk_data]     /home/dradcenko/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# [nltk_data] Downloading package punkt to /home/dradcenko/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Load the reuters corpus
from nltk.corpus import reuters

# %% [markdown]
# # Preprocess Corpus

# %%
# Retrieve the text from the Reuters Corpus
rawtext = reuters.raw()

# Transform all letters to lowercase
lowertext = rawtext.lower()

# Remove anything that's not a letter from the corpus
text = re.sub('[^a-zA-Z]+', ' ', lowertext)

# Tokenize the modified corpus
corpus = word_tokenize(text, language='english')

# Transform corpus into a list for later use 
list_ = ' '.join(corpus)
corpus
# Out:
# ['asian',
#  'exporters',
#  'fear',
#  'damage',
#  'from',
#  'u',
#  's',
#  'japan',
#  'rift',
#  'mounting',
#  'trade',
#  'friction',
#  'between',
#  'the',
#  'u',
#  's',
#  'and',
#  'japan',
#  'has',
#  'raised',
#  'fears',
#  'among',
#  'many',
#  'of',
#  'asia',
#  's',
#  'exporting',
#  'nations',
#  'that',
#  'the',
#  'row',
#  'could',
#  'inflict',
#  'far',
#  'reaching',
#  'economic',
#  'damage',
#  'businessmen',
#  'and',
#  'officials',
#  'said',
#  'they',
#  'told',
#  'reuter',
#  'correspondents',
#  'in',
#  'asian',
#  'capitals',
#  'a',
#  'u',
#  's',
#  'move',
#  'against',
#  'japan',
#  'might',
#  'boost',
#  'protectionist',
#  'sentiment',
#  'in',
#  'the',
#  'u',
#  's',
#  'and',
#  'lead',
#  'to',
#  'curbs',
#  'on',
#  'american',
#  'imports',
#  'of',
#  'their',
#  'products',
#  'but',
#  'some',
#  'exporters',
#  'said',
#  'that',
#  'while',
#  'the',
#  'conflict',
#  'would',
#  'hurt',
#  'them',
#  'in',
#  'the',
#  'long',
#  'run',
#  'in',
#  'the',
#  'short',
#  'term',
#  'tokyo',
#  's',
#  'loss',
#  'might',
#  'be',
#  'their',
#  'gain',
#  'the',
#  'u',
#  's',
#  'has',
#  'said',
#  'it',
#  'will',
#  'impose',
#  'mln',
#  'dlrs',
#  'of',
#  'tariffs',
#  'on',
#  'imports',
#  'of',
#  'japanese',
#  'electronics',
#  'goods',
#  'on',
#  'april',
#  'in',
#  'retaliation',
#  'for',
#  'japan',
#  's',
#  'alleged',
#  'failure',
#  'to',
#  'stick',
#  'to',
#  'a',
#  'pact',
#  'not',
#  'to',
#  'sell',
#  'semiconductors',
#  'on',
#  'world',
#  'markets',
#  'at',
#  'below',
#  'cost',
#  'unofficial',
#  'japanese',
#  'estimates',
#  'put',
#  'the',
#  'impact',
#  'of',
#  'the',
#  'tariffs',
#  'at',
#  'billion',
#  'dlrs',
#  'and',
#  'spokesmen',
#  'for',
#  'major',
#  'electronics',
#  'firms',
#  'said',
#  'they',
#  'would',
#  'virtually',
#  'halt',
#  'exports',
#  'of',
#  'products',
#  'hit',
#  'by',
#  'the',
#  'new',
#  'taxes',
#  'we',
#  'wouldn',
#  't',
#  'be',
#  'able',
#  'to',
#  'do',
#  'business',
#  'said',
#  'a',
#  'spokesman',
#  'for',
#  'leading',
#  'japanese',
#  'electronics',
#  'firm',
#  'matsushita',
#  'electric',
#  'industrial',
#  'co',
#  'ltd',
#  'lt',
#  'mc',
#  't',
#  'if',
#  'the',
#  'tariffs',
#  'remain',
#  'in',
#  'place',
#  'for',
#  'any',
#  'length',
#  'of',
#  'time',
#  'beyond',
#  'a',
#  'few',
#  'months',
#  'it',
#  'will',
#  'mean',
#  'the',
#  'complete',
#  'erosion',
#  'of',
#  'exports',
#  'of',
#  'goods',
#  'subject',
#  'to',
#  'tariffs',
#  'to',
#  'the',
#  'u',
#  's',
#  'said',
#  'tom',
#  'murtha',
#  'a',
#  'stock',
#  'analyst',
#  'at',
#  'the',
#  'tokyo',
#  'office',
#  'of',
#  'broker',
#  'lt',
#  'james',
#  'capel',
#  'and',
#  'co',
#  'in',
#  'taiwan',
#  'businessmen',
#  'and',
#  'officials',
#  'are',
#  'also',
#  'worried',
#  'we',
#  'are',
#  'aware',
#  'of',
#  'the',
#  'seriousness',
#  'of',
#  'the',
#  'u',
#  's',
#  'threat',
#  'against',
#  'japan',
#  'because',
#  'it',
#  'serves',
#  'as',
#  'a',
#  'warning',
#  'to',
#  'us',
#  'said',
#  'a',
#  'senior',
#  'taiwanese',
#  'trade',
#  'official',
#  'who',
#  'asked',
#  'not',
#  'to',
#  'be',
#  'named',
#  'taiwan',
#  'had',
#  'a',
#  'trade',
#  'trade',
#  'surplus',
#  'of',
#  'billion',
#  'dlrs',
#  'last',
#  'year',
#  'pct',
#  'of',
#  'it',
#  'with',
#  'the',
#  'u',
#  's',
#  'the',
#  'surplus',
#  'helped',
#  'swell',
#  'taiwan',
#  's',
#  'foreign',
#  'exchange',
#  'reserves',
#  'to',
#  'billion',
#  'dlrs',
#  'among',
#  'the',
#  'world',
#  's',
#  'largest',
#  'we',
#  'must',
#  'quickly',
#  'open',
#  'our',
#  'markets',
#  'remove',
#  'trade',
#  'barriers',
#  'and',
#  'cut',
#  'import',
#  'tariffs',
#  'to',
#  'allow',
#  'imports',
#  'of',
#  'u',
#  's',
#  'products',
#  'if',
#  'we',
#  'want',
#  'to',
#  'defuse',
#  'problems',
#  'from',
#  'possible',
#  'u',
#  's',
#  'retaliation',
#  'said',
#  'paul',
#  'sheen',
#  'chairman',
#  'of',
#  'textile',
#  'exporters',
#  'lt',
#  'taiwan',
#  'safe',
#  'group',
#  'a',
#  'senior',
#  'official',
#  'of',
#  'south',
#  'korea',
#  's',
#  'trade',
#  'promotion',
#  'association',
#  'said',
#  'the',
#  'trade',
#  'dispute',
#  'between',
#  'the',
#  'u',
#  's',
#  'and',
#  'japan',
#  'might',
#  'also',
#  'lead',
#  'to',
#  'pressure',
#  'on',
#  'south',
#  'korea',
#  'whose',
#  'chief',
#  'exports',
#  'are',
#  'similar',
#  'to',
#  'those',
#  'of',
#  'japan',
#  'last',
#  'year',
#  'south',
#  'korea',
#  'had',
#  'a',
#  'trade',
#  'surplus',
#  'of',
#  'billion',
#  'dlrs',
#  'with',
#  'the',
#  'u',
#  's',
#  'up',
#  'from',
#  'billion',
#  'dlrs',
#  'in',
#  'in',
#  'malaysia',
#  'trade',
#  'officers',
#  'and',
#  'businessmen',
#  'said',
#  'tough',
#  'curbs',
#  'against',
#  'japan',
#  'might',
#  'allow',
#  'hard',
#  'hit',
#  'producers',
#  'of',
#  'semiconductors',
#  'in',
#  'third',
#  'countries',
#  'to',
#  'expand',
#  'their',
#  'sales',
#  'to',
#  'the',
#  'u',
#  's',
#  'in',
#  'hong',
#  'kong',
#  'where',
#  'newspapers',
#  'have',
#  'alleged',
#  'japan',
#  'has',
#  'been',
#  'selling',
#  'below',
#  'cost',
#  'semiconductors',
#  'some',
#  'electronics',
#  'manufacturers',
#  'share',
#  'that',
#  'view',
#  'but',
#  'other',
#  'businessmen',
#  'said',
#  'such',
#  'a',
#  'short',
#  'term',
#  'commercial',
#  'advantage',
#  'would',
#  'be',
#  'outweighed',
#  'by',
#  'further',
#  'u',
#  's',
#  'pressure',
#  'to',
#  'block',
#  'imports',
#  'that',
#  'is',
#  'a',
#  'very',
#  'short',
#  'term',
#  'view',
#  'said',
#  'lawrence',
#  'mills',
#  'director',
#  'general',
#  'of',
#  'the',
#  'federation',
#  'of',
#  'hong',
#  'kong',
#  'industry',
#  'if',
#  'the',
#  'whole',
#  'purpose',
#  'is',
#  'to',
#  'prevent',
#  'imports',
#  'one',
#  'day',
#  'it',
#  'will',
#  'be',
#  'extended',
#  'to',
#  'other',
#  'sources',
#  'much',
#  'more',
#  'serious',
#  'for',
#  'hong',
#  'kong',
#  'is',
#  'the',
#  'disadvantage',
#  'of',
#  'action',
#  'restraining',
#  'trade',
#  'he',
#  'said',
#  'the',
#  'u',
#  's',
#  'last',
#  'year',
#  'was',
#  'hong',
#  'kong',
#  's',
#  'biggest',
#  'export',
#  'market',
#  'accounting',
#  'for',
#  'over',
#  'pct',
#  'of',
#  'domestically',
#  'produced',
#  'exports',
#  'the',
#  'australian',
#  'government',
#  'is',
#  'awaiting',
#  'the',
#  'outcome',
#  'of',
#  'trade',
#  'talks',
#  'between',
#  'the',
#  'u',
#  's',
#  'and',
#  'japan',
#  'with',
#  'interest',
#  'and',
#  'concern',
#  'industry',
#  'minister',
#  'john',
#  'button',
#  'said',
#  'in',
#  'canberra',
#  'last',
#  'friday',
#  'this',
#  'kind',
#  'of',
#  'deterioration',
#  'in',
#  'trade',
#  'relations',
#  'between',
#  'two',
#  'countries',
#  'which',
#  'are',
#  'major',
#  'trading',
#  'partners',
#  'of',
#  'ours',
#  'is',
#  'a',
#  'very',
#  'serious',
#  'matter',
#  'button',
#  'said',
#  'he',
#  'said',
#  'australia',
#  's',
#  'concerns',
#  'centred',
#  'on',
#  'coal',
#  'and',
#  'beef',
#  'australia',
#  's',
#  'two',
#  'largest',
#  'exports',
#  'to',
#  'japan',
#  'and',
#  'also',
#  'significant',
#  'u',
#  's',
#  'exports',
#  'to',
#  'that',
#  'country',
#  'meanwhile',
#  'u',
#  's',
#  'japanese',
#  'diplomatic',
#  'manoeuvres',
#  'to',
#  'solve',
#  'the',
#  'trade',
#  'stand',
#  'off',
#  'continue',
#  'japan',
#  's',
#  'ruling',
#  'liberal',
#  'democratic',
#  'party',
#  'yesterday',
#  'outlined',
#  'a',
#  'package',
#  'of',
#  'economic',
#  'measures',
#  'to',
#  'boost',
#  'the',
#  'japanese',
#  'economy',
#  'the',
#  'measures',
#  'proposed',
#  'include',
#  'a',
#  'large',
#  'supplementary',
#  'budget',
#  'and',
#  'record',
#  'public',
#  'works',
#  'spending',
#  'in',
#  'the',
#  'first',
#  'half',
#  'of',
#  'the',
#  'financial',
#  'year',
#  'they',
#  'also',
#  'call',
#  'for',
#  'stepped',
#  'up',
#  'spending',
#  'as',
#  'an',
#  'emergency',
#  'measure',
#  'to',
#  'stimulate',
#  'the',
#  'economy',
#  'despite',
#  'prime',
#  'minister',
#  'yasuhiro',
#  'nakasone',
#  's',
#  'avowed',
#  'fiscal',
#  'reform',
#  'program',
#  'deputy',
#  'u',
#  's',
#  'trade',
#  'representative',
#  'michael',
#  'smith',
#  'and',
#  'makoto',
#  'kuroda',
#  'japan',
#  's',
#  'deputy',
#  'minister',
#  'of',
#  'international',
#  'trade',
#  'and',
#  'industry',
#  'miti',
#  'are',
#  'due',
#  'to',
#  'meet',
#  'in',
#  'washington',
#  'this',
#  'week',
#  'in',
#  'an',
#  'effort',
#  'to',
#  'end',
#  'the',
#  'dispute',
#  'china',
#  'daily',
#  'says',
#  'vermin',
#  'eat',
#  'pct',
#  'grain',
#  'stocks',
#  'a',
#  'survey',
#  'of',
#  'provinces',
#  'and',
#  'seven',
#  'cities',
#  'showed',
#  'vermin',
#  'consume',
#  'between',
#  'seven',
#  'and',
#  'pct',
#  'of',
#  'china',
#  's',
#  'grain',
#  'stocks',
#  'the',
#  'china',
#  'daily',
#  'said',
#  'it',
#  'also',
#  'said',
#  'that',
#  'each',
#  'year',
#  'mln',
#  'tonnes',
#  'or',
#  'pct',
#  'of',
#  'china',
#  's',
#  'fruit',
#  'output',
#  'are',
#  'left',
#  'to',
#  'rot',
#  'and',
#  'mln',
#  'tonnes',
#  'or',
#  'up',
#  'to',
#  'pct',
#  'of',
#  'its',
#  'vegetables',
#  'the',
#  'paper',
#  'blamed',
#  'the',
#  'waste',
#  'on',
#  'inadequate',
#  'storage',
#  'and',
#  'bad',
#  'preservation',
#  'methods',
#  'it',
#  'said',
#  'the',
#  'government',
#  'had',
#  'launched',
#  'a',
#  'national',
#  'programme',
#  'to',
#  'reduce',
#  'waste',
#  'calling',
#  'for',
#  'improved',
#  'technology',
#  'in',
#  'storage',
#  'and',
#  'preservation',
#  'and',
#  'greater',
#  'production',
#  'of',
#  'additives',
#  'the',
#  'paper',
#  'gave',
#  'no',
#  'further',
#  'details',
#  'japan',
#  'to',
#  'revise',
#  'long',
#  'term',
#  'energy',
#  'demand',
#  'downwards',
#  'the',
#  'ministry',
#  'of',
#  'international',
#  'trade',
#  'and',
#  'industry',
#  'miti',
#  'will',
#  'revise',
#  'its',
#  'long',
#  'term',
#  'energy',
#  'supply',
#  'demand',
#  'outlook',
#  'by',
#  'august',
#  'to',
#  'meet',
#  'a',
#  'forecast',
#  'downtrend',
#  'in',
#  'japanese',
#  'energy',
#  'demand',
#  'ministry',
#  'officials',
#  'said',
#  'miti',
#  'is',
#  'expected',
#  'to',
#  'lower',
#  'the',
#  'projection',
#  'for',
#  'primary',
#  'energy',
#  'supplies',
#  'in',
#  'the',
#  'year',
#  'to',
#  'mln',
#  'kilolitres',
#  'kl',
#  'from',
#  'mln',
#  'they',
#  'said',
#  'the',
#  'decision',
#  'follows',
#  'the',
#  'emergence',
#  'of',
#  'structural',
#  'changes',
#  'in',
#  'japanese',
#  'industry',
#  'following',
#  'the',
#  'rise',
#  'in',
#  'the',
#  'value',
#  'of',
#  'the',
#  'yen',
#  'and',
#  'a',
#  'decline',
#  'in',
#  'domestic',
#  'electric',
#  'power',
#  'demand',
#  'miti',
#  'is',
#  'planning',
#  'to',
#  'work',
#  'out',
#  'a',
#  'revised',
#  'energy',
#  'supply',
#  'demand',
#  'outlook',
#  'through',
#  'deliberations',
#  'of',
#  'committee',
#  'meetings',
#  'of',
#  'the',
#  'agency',
#  'of',
#  'natural',
#  'resources',
#  'and',
#  'energy',
#  'the',
#  'officials',
#  'said',
#  'they',
#  'said',
#  'miti',
#  'will',
#  'also',
#  'review',
#  'the',
#  'breakdown',
#  'of',
#  'energy',
#  'supply',
#  'sources',
#  'including',
#  'oil',
#  'nuclear',
#  'coal',
#  'and',
#  'natural',
#  'gas',
#  'nuclear',
#  'energy',
#  'provided',
#  'the',
#  'bulk',
#  'of',
#  'japan',
#  's',
#  'electric',
#  'power',
#  ...]

# %% [markdown]
# # Create Function to generate N-Grams

# %%
def generate_ngrams(text, n): 
    words = text.split()
    alist = [] 
    for i in range (len(words)- n+1):
        alist.append(words[i:i+n])
    return alist

# %% [markdown]
# Here, we split a given list into words and create sublists of n words which we then store in the empty list alist.

# %%
# Generate exemplary N-Gram for n = 7
generate_ngrams(list_, 7)
# Out:
# [['asian', 'exporters', 'fear', 'damage', 'from', 'u', 's'],
#  ['exporters', 'fear', 'damage', 'from', 'u', 's', 'japan'],
#  ['fear', 'damage', 'from', 'u', 's', 'japan', 'rift'],
#  ['damage', 'from', 'u', 's', 'japan', 'rift', 'mounting'],
#  ['from', 'u', 's', 'japan', 'rift', 'mounting', 'trade'],
#  ['u', 's', 'japan', 'rift', 'mounting', 'trade', 'friction'],
#  ['s', 'japan', 'rift', 'mounting', 'trade', 'friction', 'between'],
#  ['japan', 'rift', 'mounting', 'trade', 'friction', 'between', 'the'],
#  ['rift', 'mounting', 'trade', 'friction', 'between', 'the', 'u'],
#  ['mounting', 'trade', 'friction', 'between', 'the', 'u', 's'],
#  ['trade', 'friction', 'between', 'the', 'u', 's', 'and'],
#  ['friction', 'between', 'the', 'u', 's', 'and', 'japan'],
#  ['between', 'the', 'u', 's', 'and', 'japan', 'has'],
#  ['the', 'u', 's', 'and', 'japan', 'has', 'raised'],
#  ['u', 's', 'and', 'japan', 'has', 'raised', 'fears'],
#  ['s', 'and', 'japan', 'has', 'raised', 'fears', 'among'],
#  ['and', 'japan', 'has', 'raised', 'fears', 'among', 'many'],
#  ['japan', 'has', 'raised', 'fears', 'among', 'many', 'of'],
#  ['has', 'raised', 'fears', 'among', 'many', 'of', 'asia'],
#  ['raised', 'fears', 'among', 'many', 'of', 'asia', 's'],
#  ['fears', 'among', 'many', 'of', 'asia', 's', 'exporting'],
#  ['among', 'many', 'of', 'asia', 's', 'exporting', 'nations'],
#  ['many', 'of', 'asia', 's', 'exporting', 'nations', 'that'],
#  ['of', 'asia', 's', 'exporting', 'nations', 'that', 'the'],
#  ['asia', 's', 'exporting', 'nations', 'that', 'the', 'row'],
#  ['s', 'exporting', 'nations', 'that', 'the', 'row', 'could'],
#  ['exporting', 'nations', 'that', 'the', 'row', 'could', 'inflict'],
#  ['nations', 'that', 'the', 'row', 'could', 'inflict', 'far'],
#  ['that', 'the', 'row', 'could', 'inflict', 'far', 'reaching'],
#  ['the', 'row', 'could', 'inflict', 'far', 'reaching', 'economic'],
#  ['row', 'could', 'inflict', 'far', 'reaching', 'economic', 'damage'],
#  ['could', 'inflict', 'far', 'reaching', 'economic', 'damage', 'businessmen'],
#  ['inflict', 'far', 'reaching', 'economic', 'damage', 'businessmen', 'and'],
#  ['far', 'reaching', 'economic', 'damage', 'businessmen', 'and', 'officials'],
#  ['reaching', 'economic', 'damage', 'businessmen', 'and', 'officials', 'said'],
#  ['economic', 'damage', 'businessmen', 'and', 'officials', 'said', 'they'],
#  ['damage', 'businessmen', 'and', 'officials', 'said', 'they', 'told'],
#  ['businessmen', 'and', 'officials', 'said', 'they', 'told', 'reuter'],
#  ['and', 'officials', 'said', 'they', 'told', 'reuter', 'correspondents'],
#  ['officials', 'said', 'they', 'told', 'reuter', 'correspondents', 'in'],
#  ['said', 'they', 'told', 'reuter', 'correspondents', 'in', 'asian'],
#  ['they', 'told', 'reuter', 'correspondents', 'in', 'asian', 'capitals'],
#  ['told', 'reuter', 'correspondents', 'in', 'asian', 'capitals', 'a'],
#  ['reuter', 'correspondents', 'in', 'asian', 'capitals', 'a', 'u'],
#  ['correspondents', 'in', 'asian', 'capitals', 'a', 'u', 's'],
#  ['in', 'asian', 'capitals', 'a', 'u', 's', 'move'],
#  ['asian', 'capitals', 'a', 'u', 's', 'move', 'against'],
#  ['capitals', 'a', 'u', 's', 'move', 'against', 'japan'],
#  ['a', 'u', 's', 'move', 'against', 'japan', 'might'],
#  ['u', 's', 'move', 'against', 'japan', 'might', 'boost'],
#  ['s', 'move', 'against', 'japan', 'might', 'boost', 'protectionist'],
#  ['move', 'against', 'japan', 'might', 'boost', 'protectionist', 'sentiment'],
#  ['against', 'japan', 'might', 'boost', 'protectionist', 'sentiment', 'in'],
#  ['japan', 'might', 'boost', 'protectionist', 'sentiment', 'in', 'the'],
#  ['might', 'boost', 'protectionist', 'sentiment', 'in', 'the', 'u'],
#  ['boost', 'protectionist', 'sentiment', 'in', 'the', 'u', 's'],
#  ['protectionist', 'sentiment', 'in', 'the', 'u', 's', 'and'],
#  ['sentiment', 'in', 'the', 'u', 's', 'and', 'lead'],
#  ['in', 'the', 'u', 's', 'and', 'lead', 'to'],
#  ['the', 'u', 's', 'and', 'lead', 'to', 'curbs'],
#  ['u', 's', 'and', 'lead', 'to', 'curbs', 'on'],
#  ['s', 'and', 'lead', 'to', 'curbs', 'on', 'american'],
#  ['and', 'lead', 'to', 'curbs', 'on', 'american', 'imports'],
#  ['lead', 'to', 'curbs', 'on', 'american', 'imports', 'of'],
#  ['to', 'curbs', 'on', 'american', 'imports', 'of', 'their'],
#  ['curbs', 'on', 'american', 'imports', 'of', 'their', 'products'],
#  ['on', 'american', 'imports', 'of', 'their', 'products', 'but'],
#  ['american', 'imports', 'of', 'their', 'products', 'but', 'some'],
#  ['imports', 'of', 'their', 'products', 'but', 'some', 'exporters'],
#  ['of', 'their', 'products', 'but', 'some', 'exporters', 'said'],
#  ['their', 'products', 'but', 'some', 'exporters', 'said', 'that'],
#  ['products', 'but', 'some', 'exporters', 'said', 'that', 'while'],
#  ['but', 'some', 'exporters', 'said', 'that', 'while', 'the'],
#  ['some', 'exporters', 'said', 'that', 'while', 'the', 'conflict'],
#  ['exporters', 'said', 'that', 'while', 'the', 'conflict', 'would'],
#  ['said', 'that', 'while', 'the', 'conflict', 'would', 'hurt'],
#  ['that', 'while', 'the', 'conflict', 'would', 'hurt', 'them'],
#  ['while', 'the', 'conflict', 'would', 'hurt', 'them', 'in'],
#  ['the', 'conflict', 'would', 'hurt', 'them', 'in', 'the'],
#  ['conflict', 'would', 'hurt', 'them', 'in', 'the', 'long'],
#  ['would', 'hurt', 'them', 'in', 'the', 'long', 'run'],
#  ['hurt', 'them', 'in', 'the', 'long', 'run', 'in'],
#  ['them', 'in', 'the', 'long', 'run', 'in', 'the'],
#  ['in', 'the', 'long', 'run', 'in', 'the', 'short'],
#  ['the', 'long', 'run', 'in', 'the', 'short', 'term'],
#  ['long', 'run', 'in', 'the', 'short', 'term', 'tokyo'],
#  ['run', 'in', 'the', 'short', 'term', 'tokyo', 's'],
#  ['in', 'the', 'short', 'term', 'tokyo', 's', 'loss'],
#  ['the', 'short', 'term', 'tokyo', 's', 'loss', 'might'],
#  ['short', 'term', 'tokyo', 's', 'loss', 'might', 'be'],
#  ['term', 'tokyo', 's', 'loss', 'might', 'be', 'their'],
#  ['tokyo', 's', 'loss', 'might', 'be', 'their', 'gain'],
#  ['s', 'loss', 'might', 'be', 'their', 'gain', 'the'],
#  ['loss', 'might', 'be', 'their', 'gain', 'the', 'u'],
#  ['might', 'be', 'their', 'gain', 'the', 'u', 's'],
#  ['be', 'their', 'gain', 'the', 'u', 's', 'has'],
#  ['their', 'gain', 'the', 'u', 's', 'has', 'said'],
#  ['gain', 'the', 'u', 's', 'has', 'said', 'it'],
#  ['the', 'u', 's', 'has', 'said', 'it', 'will'],
#  ['u', 's', 'has', 'said', 'it', 'will', 'impose'],
#  ['s', 'has', 'said', 'it', 'will', 'impose', 'mln'],
#  ['has', 'said', 'it', 'will', 'impose', 'mln', 'dlrs'],
#  ['said', 'it', 'will', 'impose', 'mln', 'dlrs', 'of'],
#  ['it', 'will', 'impose', 'mln', 'dlrs', 'of', 'tariffs'],
#  ['will', 'impose', 'mln', 'dlrs', 'of', 'tariffs', 'on'],
#  ['impose', 'mln', 'dlrs', 'of', 'tariffs', 'on', 'imports'],
#  ['mln', 'dlrs', 'of', 'tariffs', 'on', 'imports', 'of'],
#  ['dlrs', 'of', 'tariffs', 'on', 'imports', 'of', 'japanese'],
#  ['of', 'tariffs', 'on', 'imports', 'of', 'japanese', 'electronics'],
#  ['tariffs', 'on', 'imports', 'of', 'japanese', 'electronics', 'goods'],
#  ['on', 'imports', 'of', 'japanese', 'electronics', 'goods', 'on'],
#  ['imports', 'of', 'japanese', 'electronics', 'goods', 'on', 'april'],
#  ['of', 'japanese', 'electronics', 'goods', 'on', 'april', 'in'],
#  ['japanese', 'electronics', 'goods', 'on', 'april', 'in', 'retaliation'],
#  ['electronics', 'goods', 'on', 'april', 'in', 'retaliation', 'for'],
#  ['goods', 'on', 'april', 'in', 'retaliation', 'for', 'japan'],
#  ['on', 'april', 'in', 'retaliation', 'for', 'japan', 's'],
#  ['april', 'in', 'retaliation', 'for', 'japan', 's', 'alleged'],
#  ['in', 'retaliation', 'for', 'japan', 's', 'alleged', 'failure'],
#  ['retaliation', 'for', 'japan', 's', 'alleged', 'failure', 'to'],
#  ['for', 'japan', 's', 'alleged', 'failure', 'to', 'stick'],
#  ['japan', 's', 'alleged', 'failure', 'to', 'stick', 'to'],
#  ['s', 'alleged', 'failure', 'to', 'stick', 'to', 'a'],
#  ['alleged', 'failure', 'to', 'stick', 'to', 'a', 'pact'],
#  ['failure', 'to', 'stick', 'to', 'a', 'pact', 'not'],
#  ['to', 'stick', 'to', 'a', 'pact', 'not', 'to'],
#  ['stick', 'to', 'a', 'pact', 'not', 'to', 'sell'],
#  ['to', 'a', 'pact', 'not', 'to', 'sell', 'semiconductors'],
#  ['a', 'pact', 'not', 'to', 'sell', 'semiconductors', 'on'],
#  ['pact', 'not', 'to', 'sell', 'semiconductors', 'on', 'world'],
#  ['not', 'to', 'sell', 'semiconductors', 'on', 'world', 'markets'],
#  ['to', 'sell', 'semiconductors', 'on', 'world', 'markets', 'at'],
#  ['sell', 'semiconductors', 'on', 'world', 'markets', 'at', 'below'],
#  ['semiconductors', 'on', 'world', 'markets', 'at', 'below', 'cost'],
#  ['on', 'world', 'markets', 'at', 'below', 'cost', 'unofficial'],
#  ['world', 'markets', 'at', 'below', 'cost', 'unofficial', 'japanese'],
#  ['markets', 'at', 'below', 'cost', 'unofficial', 'japanese', 'estimates'],
#  ['at', 'below', 'cost', 'unofficial', 'japanese', 'estimates', 'put'],
#  ['below', 'cost', 'unofficial', 'japanese', 'estimates', 'put', 'the'],
#  ['cost', 'unofficial', 'japanese', 'estimates', 'put', 'the', 'impact'],
#  ['unofficial', 'japanese', 'estimates', 'put', 'the', 'impact', 'of'],
#  ['japanese', 'estimates', 'put', 'the', 'impact', 'of', 'the'],
#  ['estimates', 'put', 'the', 'impact', 'of', 'the', 'tariffs'],
#  ['put', 'the', 'impact', 'of', 'the', 'tariffs', 'at'],
#  ['the', 'impact', 'of', 'the', 'tariffs', 'at', 'billion'],
#  ['impact', 'of', 'the', 'tariffs', 'at', 'billion', 'dlrs'],
#  ['of', 'the', 'tariffs', 'at', 'billion', 'dlrs', 'and'],
#  ['the', 'tariffs', 'at', 'billion', 'dlrs', 'and', 'spokesmen'],
#  ['tariffs', 'at', 'billion', 'dlrs', 'and', 'spokesmen', 'for'],
#  ['at', 'billion', 'dlrs', 'and', 'spokesmen', 'for', 'major'],
#  ['billion', 'dlrs', 'and', 'spokesmen', 'for', 'major', 'electronics'],
#  ['dlrs', 'and', 'spokesmen', 'for', 'major', 'electronics', 'firms'],
#  ['and', 'spokesmen', 'for', 'major', 'electronics', 'firms', 'said'],
#  ['spokesmen', 'for', 'major', 'electronics', 'firms', 'said', 'they'],
#  ['for', 'major', 'electronics', 'firms', 'said', 'they', 'would'],
#  ['major', 'electronics', 'firms', 'said', 'they', 'would', 'virtually'],
#  ['electronics', 'firms', 'said', 'they', 'would', 'virtually', 'halt'],
#  ['firms', 'said', 'they', 'would', 'virtually', 'halt', 'exports'],
#  ['said', 'they', 'would', 'virtually', 'halt', 'exports', 'of'],
#  ['they', 'would', 'virtually', 'halt', 'exports', 'of', 'products'],
#  ['would', 'virtually', 'halt', 'exports', 'of', 'products', 'hit'],
#  ['virtually', 'halt', 'exports', 'of', 'products', 'hit', 'by'],
#  ['halt', 'exports', 'of', 'products', 'hit', 'by', 'the'],
#  ['exports', 'of', 'products', 'hit', 'by', 'the', 'new'],
#  ['of', 'products', 'hit', 'by', 'the', 'new', 'taxes'],
#  ['products', 'hit', 'by', 'the', 'new', 'taxes', 'we'],
#  ['hit', 'by', 'the', 'new', 'taxes', 'we', 'wouldn'],
#  ['by', 'the', 'new', 'taxes', 'we', 'wouldn', 't'],
#  ['the', 'new', 'taxes', 'we', 'wouldn', 't', 'be'],
#  ['new', 'taxes', 'we', 'wouldn', 't', 'be', 'able'],
#  ['taxes', 'we', 'wouldn', 't', 'be', 'able', 'to'],
#  ['we', 'wouldn', 't', 'be', 'able', 'to', 'do'],
#  ['wouldn', 't', 'be', 'able', 'to', 'do', 'business'],
#  ['t', 'be', 'able', 'to', 'do', 'business', 'said'],
#  ['be', 'able', 'to', 'do', 'business', 'said', 'a'],
#  ['able', 'to', 'do', 'business', 'said', 'a', 'spokesman'],
#  ['to', 'do', 'business', 'said', 'a', 'spokesman', 'for'],
#  ['do', 'business', 'said', 'a', 'spokesman', 'for', 'leading'],
#  ['business', 'said', 'a', 'spokesman', 'for', 'leading', 'japanese'],
#  ['said', 'a', 'spokesman', 'for', 'leading', 'japanese', 'electronics'],
#  ['a', 'spokesman', 'for', 'leading', 'japanese', 'electronics', 'firm'],
#  ['spokesman',
#   'for',
#   'leading',
#   'japanese',
#   'electronics',
#   'firm',
#   'matsushita'],
#  ['for',
#   'leading',
#   'japanese',
#   'electronics',
#   'firm',
#   'matsushita',
#   'electric'],
#  ['leading',
#   'japanese',
#   'electronics',
#   'firm',
#   'matsushita',
#   'electric',
#   'industrial'],
#  ['japanese',
#   'electronics',
#   'firm',
#   'matsushita',
#   'electric',
#   'industrial',
#   'co'],
#  ['electronics', 'firm', 'matsushita', 'electric', 'industrial', 'co', 'ltd'],
#  ['firm', 'matsushita', 'electric', 'industrial', 'co', 'ltd', 'lt'],
#  ['matsushita', 'electric', 'industrial', 'co', 'ltd', 'lt', 'mc'],
#  ['electric', 'industrial', 'co', 'ltd', 'lt', 'mc', 't'],
#  ['industrial', 'co', 'ltd', 'lt', 'mc', 't', 'if'],
#  ['co', 'ltd', 'lt', 'mc', 't', 'if', 'the'],
#  ['ltd', 'lt', 'mc', 't', 'if', 'the', 'tariffs'],
#  ['lt', 'mc', 't', 'if', 'the', 'tariffs', 'remain'],
#  ['mc', 't', 'if', 'the', 'tariffs', 'remain', 'in'],
#  ['t', 'if', 'the', 'tariffs', 'remain', 'in', 'place'],
#  ['if', 'the', 'tariffs', 'remain', 'in', 'place', 'for'],
#  ['the', 'tariffs', 'remain', 'in', 'place', 'for', 'any'],
#  ['tariffs', 'remain', 'in', 'place', 'for', 'any', 'length'],
#  ['remain', 'in', 'place', 'for', 'any', 'length', 'of'],
#  ['in', 'place', 'for', 'any', 'length', 'of', 'time'],
#  ['place', 'for', 'any', 'length', 'of', 'time', 'beyond'],
#  ['for', 'any', 'length', 'of', 'time', 'beyond', 'a'],
#  ['any', 'length', 'of', 'time', 'beyond', 'a', 'few'],
#  ['length', 'of', 'time', 'beyond', 'a', 'few', 'months'],
#  ['of', 'time', 'beyond', 'a', 'few', 'months', 'it'],
#  ['time', 'beyond', 'a', 'few', 'months', 'it', 'will'],
#  ['beyond', 'a', 'few', 'months', 'it', 'will', 'mean'],
#  ['a', 'few', 'months', 'it', 'will', 'mean', 'the'],
#  ['few', 'months', 'it', 'will', 'mean', 'the', 'complete'],
#  ['months', 'it', 'will', 'mean', 'the', 'complete', 'erosion'],
#  ['it', 'will', 'mean', 'the', 'complete', 'erosion', 'of'],
#  ['will', 'mean', 'the', 'complete', 'erosion', 'of', 'exports'],
#  ['mean', 'the', 'complete', 'erosion', 'of', 'exports', 'of'],
#  ['the', 'complete', 'erosion', 'of', 'exports', 'of', 'goods'],
#  ['complete', 'erosion', 'of', 'exports', 'of', 'goods', 'subject'],
#  ['erosion', 'of', 'exports', 'of', 'goods', 'subject', 'to'],
#  ['of', 'exports', 'of', 'goods', 'subject', 'to', 'tariffs'],
#  ['exports', 'of', 'goods', 'subject', 'to', 'tariffs', 'to'],
#  ['of', 'goods', 'subject', 'to', 'tariffs', 'to', 'the'],
#  ['goods', 'subject', 'to', 'tariffs', 'to', 'the', 'u'],
#  ['subject', 'to', 'tariffs', 'to', 'the', 'u', 's'],
#  ['to', 'tariffs', 'to', 'the', 'u', 's', 'said'],
#  ['tariffs', 'to', 'the', 'u', 's', 'said', 'tom'],
#  ['to', 'the', 'u', 's', 'said', 'tom', 'murtha'],
#  ['the', 'u', 's', 'said', 'tom', 'murtha', 'a'],
#  ['u', 's', 'said', 'tom', 'murtha', 'a', 'stock'],
#  ['s', 'said', 'tom', 'murtha', 'a', 'stock', 'analyst'],
#  ['said', 'tom', 'murtha', 'a', 'stock', 'analyst', 'at'],
#  ['tom', 'murtha', 'a', 'stock', 'analyst', 'at', 'the'],
#  ['murtha', 'a', 'stock', 'analyst', 'at', 'the', 'tokyo'],
#  ['a', 'stock', 'analyst', 'at', 'the', 'tokyo', 'office'],
#  ['stock', 'analyst', 'at', 'the', 'tokyo', 'office', 'of'],
#  ['analyst', 'at', 'the', 'tokyo', 'office', 'of', 'broker'],
#  ['at', 'the', 'tokyo', 'office', 'of', 'broker', 'lt'],
#  ['the', 'tokyo', 'office', 'of', 'broker', 'lt', 'james'],
#  ['tokyo', 'office', 'of', 'broker', 'lt', 'james', 'capel'],
#  ['office', 'of', 'broker', 'lt', 'james', 'capel', 'and'],
#  ['of', 'broker', 'lt', 'james', 'capel', 'and', 'co'],
#  ['broker', 'lt', 'james', 'capel', 'and', 'co', 'in'],
#  ['lt', 'james', 'capel', 'and', 'co', 'in', 'taiwan'],
#  ['james', 'capel', 'and', 'co', 'in', 'taiwan', 'businessmen'],
#  ['capel', 'and', 'co', 'in', 'taiwan', 'businessmen', 'and'],
#  ['and', 'co', 'in', 'taiwan', 'businessmen', 'and', 'officials'],
#  ['co', 'in', 'taiwan', 'businessmen', 'and', 'officials', 'are'],
#  ['in', 'taiwan', 'businessmen', 'and', 'officials', 'are', 'also'],
#  ['taiwan', 'businessmen', 'and', 'officials', 'are', 'also', 'worried'],
#  ['businessmen', 'and', 'officials', 'are', 'also', 'worried', 'we'],
#  ['and', 'officials', 'are', 'also', 'worried', 'we', 'are'],
#  ['officials', 'are', 'also', 'worried', 'we', 'are', 'aware'],
#  ['are', 'also', 'worried', 'we', 'are', 'aware', 'of'],
#  ['also', 'worried', 'we', 'are', 'aware', 'of', 'the'],
#  ['worried', 'we', 'are', 'aware', 'of', 'the', 'seriousness'],
#  ['we', 'are', 'aware', 'of', 'the', 'seriousness', 'of'],
#  ['are', 'aware', 'of', 'the', 'seriousness', 'of', 'the'],
#  ['aware', 'of', 'the', 'seriousness', 'of', 'the', 'u'],
#  ['of', 'the', 'seriousness', 'of', 'the', 'u', 's'],
#  ['the', 'seriousness', 'of', 'the', 'u', 's', 'threat'],
#  ['seriousness', 'of', 'the', 'u', 's', 'threat', 'against'],
#  ['of', 'the', 'u', 's', 'threat', 'against', 'japan'],
#  ['the', 'u', 's', 'threat', 'against', 'japan', 'because'],
#  ['u', 's', 'threat', 'against', 'japan', 'because', 'it'],
#  ['s', 'threat', 'against', 'japan', 'because', 'it', 'serves'],
#  ['threat', 'against', 'japan', 'because', 'it', 'serves', 'as'],
#  ['against', 'japan', 'because', 'it', 'serves', 'as', 'a'],
#  ['japan', 'because', 'it', 'serves', 'as', 'a', 'warning'],
#  ['because', 'it', 'serves', 'as', 'a', 'warning', 'to'],
#  ['it', 'serves', 'as', 'a', 'warning', 'to', 'us'],
#  ['serves', 'as', 'a', 'warning', 'to', 'us', 'said'],
#  ['as', 'a', 'warning', 'to', 'us', 'said', 'a'],
#  ['a', 'warning', 'to', 'us', 'said', 'a', 'senior'],
#  ['warning', 'to', 'us', 'said', 'a', 'senior', 'taiwanese'],
#  ['to', 'us', 'said', 'a', 'senior', 'taiwanese', 'trade'],
#  ['us', 'said', 'a', 'senior', 'taiwanese', 'trade', 'official'],
#  ['said', 'a', 'senior', 'taiwanese', 'trade', 'official', 'who'],
#  ['a', 'senior', 'taiwanese', 'trade', 'official', 'who', 'asked'],
#  ['senior', 'taiwanese', 'trade', 'official', 'who', 'asked', 'not'],
#  ['taiwanese', 'trade', 'official', 'who', 'asked', 'not', 'to'],
#  ['trade', 'official', 'who', 'asked', 'not', 'to', 'be'],
#  ['official', 'who', 'asked', 'not', 'to', 'be', 'named'],
#  ['who', 'asked', 'not', 'to', 'be', 'named', 'taiwan'],
#  ['asked', 'not', 'to', 'be', 'named', 'taiwan', 'had'],
#  ['not', 'to', 'be', 'named', 'taiwan', 'had', 'a'],
#  ['to', 'be', 'named', 'taiwan', 'had', 'a', 'trade'],
#  ['be', 'named', 'taiwan', 'had', 'a', 'trade', 'trade'],
#  ['named', 'taiwan', 'had', 'a', 'trade', 'trade', 'surplus'],
#  ['taiwan', 'had', 'a', 'trade', 'trade', 'surplus', 'of'],
#  ['had', 'a', 'trade', 'trade', 'surplus', 'of', 'billion'],
#  ['a', 'trade', 'trade', 'surplus', 'of', 'billion', 'dlrs'],
#  ['trade', 'trade', 'surplus', 'of', 'billion', 'dlrs', 'last'],
#  ['trade', 'surplus', 'of', 'billion', 'dlrs', 'last', 'year'],
#  ['surplus', 'of', 'billion', 'dlrs', 'last', 'year', 'pct'],
#  ['of', 'billion', 'dlrs', 'last', 'year', 'pct', 'of'],
#  ['billion', 'dlrs', 'last', 'year', 'pct', 'of', 'it'],
#  ['dlrs', 'last', 'year', 'pct', 'of', 'it', 'with'],
#  ['last', 'year', 'pct', 'of', 'it', 'with', 'the'],
#  ['year', 'pct', 'of', 'it', 'with', 'the', 'u'],
#  ['pct', 'of', 'it', 'with', 'the', 'u', 's'],
#  ['of', 'it', 'with', 'the', 'u', 's', 'the'],
#  ['it', 'with', 'the', 'u', 's', 'the', 'surplus'],
#  ['with', 'the', 'u', 's', 'the', 'surplus', 'helped'],
#  ['the', 'u', 's', 'the', 'surplus', 'helped', 'swell'],
#  ['u', 's', 'the', 'surplus', 'helped', 'swell', 'taiwan'],
#  ['s', 'the', 'surplus', 'helped', 'swell', 'taiwan', 's'],
#  ['the', 'surplus', 'helped', 'swell', 'taiwan', 's', 'foreign'],
#  ['surplus', 'helped', 'swell', 'taiwan', 's', 'foreign', 'exchange'],
#  ['helped', 'swell', 'taiwan', 's', 'foreign', 'exchange', 'reserves'],
#  ['swell', 'taiwan', 's', 'foreign', 'exchange', 'reserves', 'to'],
#  ['taiwan', 's', 'foreign', 'exchange', 'reserves', 'to', 'billion'],
#  ['s', 'foreign', 'exchange', 'reserves', 'to', 'billion', 'dlrs'],
#  ['foreign', 'exchange', 'reserves', 'to', 'billion', 'dlrs', 'among'],
#  ['exchange', 'reserves', 'to', 'billion', 'dlrs', 'among', 'the'],
#  ['reserves', 'to', 'billion', 'dlrs', 'among', 'the', 'world'],
#  ['to', 'billion', 'dlrs', 'among', 'the', 'world', 's'],
#  ['billion', 'dlrs', 'among', 'the', 'world', 's', 'largest'],
#  ['dlrs', 'among', 'the', 'world', 's', 'largest', 'we'],
#  ['among', 'the', 'world', 's', 'largest', 'we', 'must'],
#  ['the', 'world', 's', 'largest', 'we', 'must', 'quickly'],
#  ['world', 's', 'largest', 'we', 'must', 'quickly', 'open'],
#  ['s', 'largest', 'we', 'must', 'quickly', 'open', 'our'],
#  ['largest', 'we', 'must', 'quickly', 'open', 'our', 'markets'],
#  ['we', 'must', 'quickly', 'open', 'our', 'markets', 'remove'],
#  ['must', 'quickly', 'open', 'our', 'markets', 'remove', 'trade'],
#  ['quickly', 'open', 'our', 'markets', 'remove', 'trade', 'barriers'],
#  ['open', 'our', 'markets', 'remove', 'trade', 'barriers', 'and'],
#  ['our', 'markets', 'remove', 'trade', 'barriers', 'and', 'cut'],
#  ['markets', 'remove', 'trade', 'barriers', 'and', 'cut', 'import'],
#  ['remove', 'trade', 'barriers', 'and', 'cut', 'import', 'tariffs'],
#  ['trade', 'barriers', 'and', 'cut', 'import', 'tariffs', 'to'],
#  ['barriers', 'and', 'cut', 'import', 'tariffs', 'to', 'allow'],
#  ['and', 'cut', 'import', 'tariffs', 'to', 'allow', 'imports'],
#  ['cut', 'import', 'tariffs', 'to', 'allow', 'imports', 'of'],
#  ['import', 'tariffs', 'to', 'allow', 'imports', 'of', 'u'],
#  ['tariffs', 'to', 'allow', 'imports', 'of', 'u', 's'],
#  ['to', 'allow', 'imports', 'of', 'u', 's', 'products'],
#  ['allow', 'imports', 'of', 'u', 's', 'products', 'if'],
#  ['imports', 'of', 'u', 's', 'products', 'if', 'we'],
#  ['of', 'u', 's', 'products', 'if', 'we', 'want'],
#  ['u', 's', 'products', 'if', 'we', 'want', 'to'],
#  ['s', 'products', 'if', 'we', 'want', 'to', 'defuse'],
#  ['products', 'if', 'we', 'want', 'to', 'defuse', 'problems'],
#  ['if', 'we', 'want', 'to', 'defuse', 'problems', 'from'],
#  ['we', 'want', 'to', 'defuse', 'problems', 'from', 'possible'],
#  ['want', 'to', 'defuse', 'problems', 'from', 'possible', 'u'],
#  ['to', 'defuse', 'problems', 'from', 'possible', 'u', 's'],
#  ['defuse', 'problems', 'from', 'possible', 'u', 's', 'retaliation'],
#  ['problems', 'from', 'possible', 'u', 's', 'retaliation', 'said'],
#  ['from', 'possible', 'u', 's', 'retaliation', 'said', 'paul'],
#  ['possible', 'u', 's', 'retaliation', 'said', 'paul', 'sheen'],
#  ['u', 's', 'retaliation', 'said', 'paul', 'sheen', 'chairman'],
#  ['s', 'retaliation', 'said', 'paul', 'sheen', 'chairman', 'of'],
#  ['retaliation', 'said', 'paul', 'sheen', 'chairman', 'of', 'textile'],
#  ['said', 'paul', 'sheen', 'chairman', 'of', 'textile', 'exporters'],
#  ['paul', 'sheen', 'chairman', 'of', 'textile', 'exporters', 'lt'],
#  ['sheen', 'chairman', 'of', 'textile', 'exporters', 'lt', 'taiwan'],
#  ['chairman', 'of', 'textile', 'exporters', 'lt', 'taiwan', 'safe'],
#  ['of', 'textile', 'exporters', 'lt', 'taiwan', 'safe', 'group'],
#  ['textile', 'exporters', 'lt', 'taiwan', 'safe', 'group', 'a'],
#  ['exporters', 'lt', 'taiwan', 'safe', 'group', 'a', 'senior'],
#  ['lt', 'taiwan', 'safe', 'group', 'a', 'senior', 'official'],
#  ['taiwan', 'safe', 'group', 'a', 'senior', 'official', 'of'],
#  ['safe', 'group', 'a', 'senior', 'official', 'of', 'south'],
#  ['group', 'a', 'senior', 'official', 'of', 'south', 'korea'],
#  ['a', 'senior', 'official', 'of', 'south', 'korea', 's'],
#  ['senior', 'official', 'of', 'south', 'korea', 's', 'trade'],
#  ['official', 'of', 'south', 'korea', 's', 'trade', 'promotion'],
#  ['of', 'south', 'korea', 's', 'trade', 'promotion', 'association'],
#  ['south', 'korea', 's', 'trade', 'promotion', 'association', 'said'],
#  ['korea', 's', 'trade', 'promotion', 'association', 'said', 'the'],
#  ['s', 'trade', 'promotion', 'association', 'said', 'the', 'trade'],
#  ['trade', 'promotion', 'association', 'said', 'the', 'trade', 'dispute'],
#  ['promotion', 'association', 'said', 'the', 'trade', 'dispute', 'between'],
#  ['association', 'said', 'the', 'trade', 'dispute', 'between', 'the'],
#  ['said', 'the', 'trade', 'dispute', 'between', 'the', 'u'],
#  ['the', 'trade', 'dispute', 'between', 'the', 'u', 's'],
#  ['trade', 'dispute', 'between', 'the', 'u', 's', 'and'],
#  ['dispute', 'between', 'the', 'u', 's', 'and', 'japan'],
#  ['between', 'the', 'u', 's', 'and', 'japan', 'might'],
#  ['the', 'u', 's', 'and', 'japan', 'might', 'also'],
#  ['u', 's', 'and', 'japan', 'might', 'also', 'lead'],
#  ['s', 'and', 'japan', 'might', 'also', 'lead', 'to'],
#  ['and', 'japan', 'might', 'also', 'lead', 'to', 'pressure'],
#  ['japan', 'might', 'also', 'lead', 'to', 'pressure', 'on'],
#  ['might', 'also', 'lead', 'to', 'pressure', 'on', 'south'],
#  ['also', 'lead', 'to', 'pressure', 'on', 'south', 'korea'],
#  ['lead', 'to', 'pressure', 'on', 'south', 'korea', 'whose'],
#  ['to', 'pressure', 'on', 'south', 'korea', 'whose', 'chief'],
#  ['pressure', 'on', 'south', 'korea', 'whose', 'chief', 'exports'],
#  ['on', 'south', 'korea', 'whose', 'chief', 'exports', 'are'],
#  ['south', 'korea', 'whose', 'chief', 'exports', 'are', 'similar'],
#  ['korea', 'whose', 'chief', 'exports', 'are', 'similar', 'to'],
#  ['whose', 'chief', 'exports', 'are', 'similar', 'to', 'those'],
#  ['chief', 'exports', 'are', 'similar', 'to', 'those', 'of'],
#  ['exports', 'are', 'similar', 'to', 'those', 'of', 'japan'],
#  ['are', 'similar', 'to', 'those', 'of', 'japan', 'last'],
#  ['similar', 'to', 'those', 'of', 'japan', 'last', 'year'],
#  ['to', 'those', 'of', 'japan', 'last', 'year', 'south'],
#  ['those', 'of', 'japan', 'last', 'year', 'south', 'korea'],
#  ['of', 'japan', 'last', 'year', 'south', 'korea', 'had'],
#  ['japan', 'last', 'year', 'south', 'korea', 'had', 'a'],
#  ['last', 'year', 'south', 'korea', 'had', 'a', 'trade'],
#  ['year', 'south', 'korea', 'had', 'a', 'trade', 'surplus'],
#  ['south', 'korea', 'had', 'a', 'trade', 'surplus', 'of'],
#  ['korea', 'had', 'a', 'trade', 'surplus', 'of', 'billion'],
#  ['had', 'a', 'trade', 'surplus', 'of', 'billion', 'dlrs'],
#  ['a', 'trade', 'surplus', 'of', 'billion', 'dlrs', 'with'],
#  ['trade', 'surplus', 'of', 'billion', 'dlrs', 'with', 'the'],
#  ['surplus', 'of', 'billion', 'dlrs', 'with', 'the', 'u'],
#  ['of', 'billion', 'dlrs', 'with', 'the', 'u', 's'],
#  ['billion', 'dlrs', 'with', 'the', 'u', 's', 'up'],
#  ['dlrs', 'with', 'the', 'u', 's', 'up', 'from'],
#  ['with', 'the', 'u', 's', 'up', 'from', 'billion'],
#  ['the', 'u', 's', 'up', 'from', 'billion', 'dlrs'],
#  ['u', 's', 'up', 'from', 'billion', 'dlrs', 'in'],
#  ['s', 'up', 'from', 'billion', 'dlrs', 'in', 'in'],
#  ['up', 'from', 'billion', 'dlrs', 'in', 'in', 'malaysia'],
#  ['from', 'billion', 'dlrs', 'in', 'in', 'malaysia', 'trade'],
#  ['billion', 'dlrs', 'in', 'in', 'malaysia', 'trade', 'officers'],
#  ['dlrs', 'in', 'in', 'malaysia', 'trade', 'officers', 'and'],
#  ['in', 'in', 'malaysia', 'trade', 'officers', 'and', 'businessmen'],
#  ['in', 'malaysia', 'trade', 'officers', 'and', 'businessmen', 'said'],
#  ['malaysia', 'trade', 'officers', 'and', 'businessmen', 'said', 'tough'],
#  ['trade', 'officers', 'and', 'businessmen', 'said', 'tough', 'curbs'],
#  ['officers', 'and', 'businessmen', 'said', 'tough', 'curbs', 'against'],
#  ['and', 'businessmen', 'said', 'tough', 'curbs', 'against', 'japan'],
#  ['businessmen', 'said', 'tough', 'curbs', 'against', 'japan', 'might'],
#  ['said', 'tough', 'curbs', 'against', 'japan', 'might', 'allow'],
#  ['tough', 'curbs', 'against', 'japan', 'might', 'allow', 'hard'],
#  ['curbs', 'against', 'japan', 'might', 'allow', 'hard', 'hit'],
#  ['against', 'japan', 'might', 'allow', 'hard', 'hit', 'producers'],
#  ['japan', 'might', 'allow', 'hard', 'hit', 'producers', 'of'],
#  ['might', 'allow', 'hard', 'hit', 'producers', 'of', 'semiconductors'],
#  ['allow', 'hard', 'hit', 'producers', 'of', 'semiconductors', 'in'],
#  ['hard', 'hit', 'producers', 'of', 'semiconductors', 'in', 'third'],
#  ['hit', 'producers', 'of', 'semiconductors', 'in', 'third', 'countries'],
#  ['producers', 'of', 'semiconductors', 'in', 'third', 'countries', 'to'],
#  ['of', 'semiconductors', 'in', 'third', 'countries', 'to', 'expand'],
#  ['semiconductors', 'in', 'third', 'countries', 'to', 'expand', 'their'],
#  ['in', 'third', 'countries', 'to', 'expand', 'their', 'sales'],
#  ['third', 'countries', 'to', 'expand', 'their', 'sales', 'to'],
#  ['countries', 'to', 'expand', 'their', 'sales', 'to', 'the'],
#  ['to', 'expand', 'their', 'sales', 'to', 'the', 'u'],
#  ['expand', 'their', 'sales', 'to', 'the', 'u', 's'],
#  ['their', 'sales', 'to', 'the', 'u', 's', 'in'],
#  ['sales', 'to', 'the', 'u', 's', 'in', 'hong'],
#  ['to', 'the', 'u', 's', 'in', 'hong', 'kong'],
#  ['the', 'u', 's', 'in', 'hong', 'kong', 'where'],
#  ['u', 's', 'in', 'hong', 'kong', 'where', 'newspapers'],
#  ['s', 'in', 'hong', 'kong', 'where', 'newspapers', 'have'],
#  ['in', 'hong', 'kong', 'where', 'newspapers', 'have', 'alleged'],
#  ['hong', 'kong', 'where', 'newspapers', 'have', 'alleged', 'japan'],
#  ['kong', 'where', 'newspapers', 'have', 'alleged', 'japan', 'has'],
#  ['where', 'newspapers', 'have', 'alleged', 'japan', 'has', 'been'],
#  ['newspapers', 'have', 'alleged', 'japan', 'has', 'been', 'selling'],
#  ['have', 'alleged', 'japan', 'has', 'been', 'selling', 'below'],
#  ['alleged', 'japan', 'has', 'been', 'selling', 'below', 'cost'],
#  ['japan', 'has', 'been', 'selling', 'below', 'cost', 'semiconductors'],
#  ['has', 'been', 'selling', 'below', 'cost', 'semiconductors', 'some'],
#  ['been', 'selling', 'below', 'cost', 'semiconductors', 'some', 'electronics'],
#  ['selling',
#   'below',
#   'cost',
#   'semiconductors',
#   'some',
#   'electronics',
#   'manufacturers'],
#  ['below',
#   'cost',
#   'semiconductors',
#   'some',
#   'electronics',
#   'manufacturers',
#   'share'],
#  ['cost',
#   'semiconductors',
#   'some',
#   'electronics',
#   'manufacturers',
#   'share',
#   'that'],
#  ['semiconductors',
#   'some',
#   'electronics',
#   'manufacturers',
#   'share',
#   'that',
#   'view'],
#  ['some', 'electronics', 'manufacturers', 'share', 'that', 'view', 'but'],
#  ['electronics', 'manufacturers', 'share', 'that', 'view', 'but', 'other'],
#  ['manufacturers', 'share', 'that', 'view', 'but', 'other', 'businessmen'],
#  ['share', 'that', 'view', 'but', 'other', 'businessmen', 'said'],
#  ['that', 'view', 'but', 'other', 'businessmen', 'said', 'such'],
#  ['view', 'but', 'other', 'businessmen', 'said', 'such', 'a'],
#  ['but', 'other', 'businessmen', 'said', 'such', 'a', 'short'],
#  ['other', 'businessmen', 'said', 'such', 'a', 'short', 'term'],
#  ['businessmen', 'said', 'such', 'a', 'short', 'term', 'commercial'],
#  ['said', 'such', 'a', 'short', 'term', 'commercial', 'advantage'],
#  ['such', 'a', 'short', 'term', 'commercial', 'advantage', 'would'],
#  ['a', 'short', 'term', 'commercial', 'advantage', 'would', 'be'],
#  ['short', 'term', 'commercial', 'advantage', 'would', 'be', 'outweighed'],
#  ['term', 'commercial', 'advantage', 'would', 'be', 'outweighed', 'by'],
#  ['commercial', 'advantage', 'would', 'be', 'outweighed', 'by', 'further'],
#  ['advantage', 'would', 'be', 'outweighed', 'by', 'further', 'u'],
#  ['would', 'be', 'outweighed', 'by', 'further', 'u', 's'],
#  ['be', 'outweighed', 'by', 'further', 'u', 's', 'pressure'],
#  ['outweighed', 'by', 'further', 'u', 's', 'pressure', 'to'],
#  ['by', 'further', 'u', 's', 'pressure', 'to', 'block'],
#  ['further', 'u', 's', 'pressure', 'to', 'block', 'imports'],
#  ['u', 's', 'pressure', 'to', 'block', 'imports', 'that'],
#  ['s', 'pressure', 'to', 'block', 'imports', 'that', 'is'],
#  ['pressure', 'to', 'block', 'imports', 'that', 'is', 'a'],
#  ['to', 'block', 'imports', 'that', 'is', 'a', 'very'],
#  ['block', 'imports', 'that', 'is', 'a', 'very', 'short'],
#  ['imports', 'that', 'is', 'a', 'very', 'short', 'term'],
#  ['that', 'is', 'a', 'very', 'short', 'term', 'view'],
#  ['is', 'a', 'very', 'short', 'term', 'view', 'said'],
#  ['a', 'very', 'short', 'term', 'view', 'said', 'lawrence'],
#  ['very', 'short', 'term', 'view', 'said', 'lawrence', 'mills'],
#  ['short', 'term', 'view', 'said', 'lawrence', 'mills', 'director'],
#  ['term', 'view', 'said', 'lawrence', 'mills', 'director', 'general'],
#  ['view', 'said', 'lawrence', 'mills', 'director', 'general', 'of'],
#  ['said', 'lawrence', 'mills', 'director', 'general', 'of', 'the'],
#  ['lawrence', 'mills', 'director', 'general', 'of', 'the', 'federation'],
#  ['mills', 'director', 'general', 'of', 'the', 'federation', 'of'],
#  ['director', 'general', 'of', 'the', 'federation', 'of', 'hong'],
#  ['general', 'of', 'the', 'federation', 'of', 'hong', 'kong'],
#  ['of', 'the', 'federation', 'of', 'hong', 'kong', 'industry'],
#  ['the', 'federation', 'of', 'hong', 'kong', 'industry', 'if'],
#  ['federation', 'of', 'hong', 'kong', 'industry', 'if', 'the'],
#  ['of', 'hong', 'kong', 'industry', 'if', 'the', 'whole'],
#  ['hong', 'kong', 'industry', 'if', 'the', 'whole', 'purpose'],
#  ['kong', 'industry', 'if', 'the', 'whole', 'purpose', 'is'],
#  ['industry', 'if', 'the', 'whole', 'purpose', 'is', 'to'],
#  ['if', 'the', 'whole', 'purpose', 'is', 'to', 'prevent'],
#  ['the', 'whole', 'purpose', 'is', 'to', 'prevent', 'imports'],
#  ['whole', 'purpose', 'is', 'to', 'prevent', 'imports', 'one'],
#  ['purpose', 'is', 'to', 'prevent', 'imports', 'one', 'day'],
#  ['is', 'to', 'prevent', 'imports', 'one', 'day', 'it'],
#  ['to', 'prevent', 'imports', 'one', 'day', 'it', 'will'],
#  ['prevent', 'imports', 'one', 'day', 'it', 'will', 'be'],
#  ['imports', 'one', 'day', 'it', 'will', 'be', 'extended'],
#  ['one', 'day', 'it', 'will', 'be', 'extended', 'to'],
#  ['day', 'it', 'will', 'be', 'extended', 'to', 'other'],
#  ['it', 'will', 'be', 'extended', 'to', 'other', 'sources'],
#  ['will', 'be', 'extended', 'to', 'other', 'sources', 'much'],
#  ['be', 'extended', 'to', 'other', 'sources', 'much', 'more'],
#  ['extended', 'to', 'other', 'sources', 'much', 'more', 'serious'],
#  ['to', 'other', 'sources', 'much', 'more', 'serious', 'for'],
#  ['other', 'sources', 'much', 'more', 'serious', 'for', 'hong'],
#  ['sources', 'much', 'more', 'serious', 'for', 'hong', 'kong'],
#  ['much', 'more', 'serious', 'for', 'hong', 'kong', 'is'],
#  ['more', 'serious', 'for', 'hong', 'kong', 'is', 'the'],
#  ['serious', 'for', 'hong', 'kong', 'is', 'the', 'disadvantage'],
#  ['for', 'hong', 'kong', 'is', 'the', 'disadvantage', 'of'],
#  ['hong', 'kong', 'is', 'the', 'disadvantage', 'of', 'action'],
#  ['kong', 'is', 'the', 'disadvantage', 'of', 'action', 'restraining'],
#  ['is', 'the', 'disadvantage', 'of', 'action', 'restraining', 'trade'],
#  ['the', 'disadvantage', 'of', 'action', 'restraining', 'trade', 'he'],
#  ['disadvantage', 'of', 'action', 'restraining', 'trade', 'he', 'said'],
#  ['of', 'action', 'restraining', 'trade', 'he', 'said', 'the'],
#  ['action', 'restraining', 'trade', 'he', 'said', 'the', 'u'],
#  ['restraining', 'trade', 'he', 'said', 'the', 'u', 's'],
#  ['trade', 'he', 'said', 'the', 'u', 's', 'last'],
#  ['he', 'said', 'the', 'u', 's', 'last', 'year'],
#  ['said', 'the', 'u', 's', 'last', 'year', 'was'],
#  ['the', 'u', 's', 'last', 'year', 'was', 'hong'],
#  ['u', 's', 'last', 'year', 'was', 'hong', 'kong'],
#  ['s', 'last', 'year', 'was', 'hong', 'kong', 's'],
#  ['last', 'year', 'was', 'hong', 'kong', 's', 'biggest'],
#  ['year', 'was', 'hong', 'kong', 's', 'biggest', 'export'],
#  ['was', 'hong', 'kong', 's', 'biggest', 'export', 'market'],
#  ['hong', 'kong', 's', 'biggest', 'export', 'market', 'accounting'],
#  ['kong', 's', 'biggest', 'export', 'market', 'accounting', 'for'],
#  ['s', 'biggest', 'export', 'market', 'accounting', 'for', 'over'],
#  ['biggest', 'export', 'market', 'accounting', 'for', 'over', 'pct'],
#  ['export', 'market', 'accounting', 'for', 'over', 'pct', 'of'],
#  ['market', 'accounting', 'for', 'over', 'pct', 'of', 'domestically'],
#  ['accounting', 'for', 'over', 'pct', 'of', 'domestically', 'produced'],
#  ['for', 'over', 'pct', 'of', 'domestically', 'produced', 'exports'],
#  ['over', 'pct', 'of', 'domestically', 'produced', 'exports', 'the'],
#  ['pct', 'of', 'domestically', 'produced', 'exports', 'the', 'australian'],
#  ['of',
#   'domestically',
#   'produced',
#   'exports',
#   'the',
#   'australian',
#   'government'],
#  ['domestically',
#   'produced',
#   'exports',
#   'the',
#   'australian',
#   'government',
#   'is'],
#  ['produced', 'exports', 'the', 'australian', 'government', 'is', 'awaiting'],
#  ['exports', 'the', 'australian', 'government', 'is', 'awaiting', 'the'],
#  ['the', 'australian', 'government', 'is', 'awaiting', 'the', 'outcome'],
#  ['australian', 'government', 'is', 'awaiting', 'the', 'outcome', 'of'],
#  ['government', 'is', 'awaiting', 'the', 'outcome', 'of', 'trade'],
#  ['is', 'awaiting', 'the', 'outcome', 'of', 'trade', 'talks'],
#  ['awaiting', 'the', 'outcome', 'of', 'trade', 'talks', 'between'],
#  ['the', 'outcome', 'of', 'trade', 'talks', 'between', 'the'],
#  ['outcome', 'of', 'trade', 'talks', 'between', 'the', 'u'],
#  ['of', 'trade', 'talks', 'between', 'the', 'u', 's'],
#  ['trade', 'talks', 'between', 'the', 'u', 's', 'and'],
#  ['talks', 'between', 'the', 'u', 's', 'and', 'japan'],
#  ['between', 'the', 'u', 's', 'and', 'japan', 'with'],
#  ['the', 'u', 's', 'and', 'japan', 'with', 'interest'],
#  ['u', 's', 'and', 'japan', 'with', 'interest', 'and'],
#  ['s', 'and', 'japan', 'with', 'interest', 'and', 'concern'],
#  ['and', 'japan', 'with', 'interest', 'and', 'concern', 'industry'],
#  ['japan', 'with', 'interest', 'and', 'concern', 'industry', 'minister'],
#  ['with', 'interest', 'and', 'concern', 'industry', 'minister', 'john'],
#  ['interest', 'and', 'concern', 'industry', 'minister', 'john', 'button'],
#  ['and', 'concern', 'industry', 'minister', 'john', 'button', 'said'],
#  ['concern', 'industry', 'minister', 'john', 'button', 'said', 'in'],
#  ['industry', 'minister', 'john', 'button', 'said', 'in', 'canberra'],
#  ['minister', 'john', 'button', 'said', 'in', 'canberra', 'last'],
#  ['john', 'button', 'said', 'in', 'canberra', 'last', 'friday'],
#  ['button', 'said', 'in', 'canberra', 'last', 'friday', 'this'],
#  ['said', 'in', 'canberra', 'last', 'friday', 'this', 'kind'],
#  ['in', 'canberra', 'last', 'friday', 'this', 'kind', 'of'],
#  ['canberra', 'last', 'friday', 'this', 'kind', 'of', 'deterioration'],
#  ['last', 'friday', 'this', 'kind', 'of', 'deterioration', 'in'],
#  ['friday', 'this', 'kind', 'of', 'deterioration', 'in', 'trade'],
#  ['this', 'kind', 'of', 'deterioration', 'in', 'trade', 'relations'],
#  ['kind', 'of', 'deterioration', 'in', 'trade', 'relations', 'between'],
#  ['of', 'deterioration', 'in', 'trade', 'relations', 'between', 'two'],
#  ['deterioration', 'in', 'trade', 'relations', 'between', 'two', 'countries'],
#  ['in', 'trade', 'relations', 'between', 'two', 'countries', 'which'],
#  ['trade', 'relations', 'between', 'two', 'countries', 'which', 'are'],
#  ['relations', 'between', 'two', 'countries', 'which', 'are', 'major'],
#  ['between', 'two', 'countries', 'which', 'are', 'major', 'trading'],
#  ['two', 'countries', 'which', 'are', 'major', 'trading', 'partners'],
#  ['countries', 'which', 'are', 'major', 'trading', 'partners', 'of'],
#  ['which', 'are', 'major', 'trading', 'partners', 'of', 'ours'],
#  ['are', 'major', 'trading', 'partners', 'of', 'ours', 'is'],
#  ['major', 'trading', 'partners', 'of', 'ours', 'is', 'a'],
#  ['trading', 'partners', 'of', 'ours', 'is', 'a', 'very'],
#  ['partners', 'of', 'ours', 'is', 'a', 'very', 'serious'],
#  ['of', 'ours', 'is', 'a', 'very', 'serious', 'matter'],
#  ['ours', 'is', 'a', 'very', 'serious', 'matter', 'button'],
#  ['is', 'a', 'very', 'serious', 'matter', 'button', 'said'],
#  ['a', 'very', 'serious', 'matter', 'button', 'said', 'he'],
#  ['very', 'serious', 'matter', 'button', 'said', 'he', 'said'],
#  ['serious', 'matter', 'button', 'said', 'he', 'said', 'australia'],
#  ['matter', 'button', 'said', 'he', 'said', 'australia', 's'],
#  ['button', 'said', 'he', 'said', 'australia', 's', 'concerns'],
#  ['said', 'he', 'said', 'australia', 's', 'concerns', 'centred'],
#  ['he', 'said', 'australia', 's', 'concerns', 'centred', 'on'],
#  ['said', 'australia', 's', 'concerns', 'centred', 'on', 'coal'],
#  ['australia', 's', 'concerns', 'centred', 'on', 'coal', 'and'],
#  ['s', 'concerns', 'centred', 'on', 'coal', 'and', 'beef'],
#  ['concerns', 'centred', 'on', 'coal', 'and', 'beef', 'australia'],
#  ['centred', 'on', 'coal', 'and', 'beef', 'australia', 's'],
#  ['on', 'coal', 'and', 'beef', 'australia', 's', 'two'],
#  ['coal', 'and', 'beef', 'australia', 's', 'two', 'largest'],
#  ['and', 'beef', 'australia', 's', 'two', 'largest', 'exports'],
#  ['beef', 'australia', 's', 'two', 'largest', 'exports', 'to'],
#  ['australia', 's', 'two', 'largest', 'exports', 'to', 'japan'],
#  ['s', 'two', 'largest', 'exports', 'to', 'japan', 'and'],
#  ['two', 'largest', 'exports', 'to', 'japan', 'and', 'also'],
#  ['largest', 'exports', 'to', 'japan', 'and', 'also', 'significant'],
#  ['exports', 'to', 'japan', 'and', 'also', 'significant', 'u'],
#  ['to', 'japan', 'and', 'also', 'significant', 'u', 's'],
#  ['japan', 'and', 'also', 'significant', 'u', 's', 'exports'],
#  ['and', 'also', 'significant', 'u', 's', 'exports', 'to'],
#  ['also', 'significant', 'u', 's', 'exports', 'to', 'that'],
#  ['significant', 'u', 's', 'exports', 'to', 'that', 'country'],
#  ['u', 's', 'exports', 'to', 'that', 'country', 'meanwhile'],
#  ['s', 'exports', 'to', 'that', 'country', 'meanwhile', 'u'],
#  ['exports', 'to', 'that', 'country', 'meanwhile', 'u', 's'],
#  ['to', 'that', 'country', 'meanwhile', 'u', 's', 'japanese'],
#  ['that', 'country', 'meanwhile', 'u', 's', 'japanese', 'diplomatic'],
#  ['country', 'meanwhile', 'u', 's', 'japanese', 'diplomatic', 'manoeuvres'],
#  ['meanwhile', 'u', 's', 'japanese', 'diplomatic', 'manoeuvres', 'to'],
#  ['u', 's', 'japanese', 'diplomatic', 'manoeuvres', 'to', 'solve'],
#  ['s', 'japanese', 'diplomatic', 'manoeuvres', 'to', 'solve', 'the'],
#  ['japanese', 'diplomatic', 'manoeuvres', 'to', 'solve', 'the', 'trade'],
#  ['diplomatic', 'manoeuvres', 'to', 'solve', 'the', 'trade', 'stand'],
#  ['manoeuvres', 'to', 'solve', 'the', 'trade', 'stand', 'off'],
#  ['to', 'solve', 'the', 'trade', 'stand', 'off', 'continue'],
#  ['solve', 'the', 'trade', 'stand', 'off', 'continue', 'japan'],
#  ['the', 'trade', 'stand', 'off', 'continue', 'japan', 's'],
#  ['trade', 'stand', 'off', 'continue', 'japan', 's', 'ruling'],
#  ['stand', 'off', 'continue', 'japan', 's', 'ruling', 'liberal'],
#  ['off', 'continue', 'japan', 's', 'ruling', 'liberal', 'democratic'],
#  ['continue', 'japan', 's', 'ruling', 'liberal', 'democratic', 'party'],
#  ['japan', 's', 'ruling', 'liberal', 'democratic', 'party', 'yesterday'],
#  ['s', 'ruling', 'liberal', 'democratic', 'party', 'yesterday', 'outlined'],
#  ['ruling', 'liberal', 'democratic', 'party', 'yesterday', 'outlined', 'a'],
#  ['liberal', 'democratic', 'party', 'yesterday', 'outlined', 'a', 'package'],
#  ['democratic', 'party', 'yesterday', 'outlined', 'a', 'package', 'of'],
#  ['party', 'yesterday', 'outlined', 'a', 'package', 'of', 'economic'],
#  ['yesterday', 'outlined', 'a', 'package', 'of', 'economic', 'measures'],
#  ['outlined', 'a', 'package', 'of', 'economic', 'measures', 'to'],
#  ['a', 'package', 'of', 'economic', 'measures', 'to', 'boost'],
#  ['package', 'of', 'economic', 'measures', 'to', 'boost', 'the'],
#  ['of', 'economic', 'measures', 'to', 'boost', 'the', 'japanese'],
#  ['economic', 'measures', 'to', 'boost', 'the', 'japanese', 'economy'],
#  ['measures', 'to', 'boost', 'the', 'japanese', 'economy', 'the'],
#  ['to', 'boost', 'the', 'japanese', 'economy', 'the', 'measures'],
#  ['boost', 'the', 'japanese', 'economy', 'the', 'measures', 'proposed'],
#  ['the', 'japanese', 'economy', 'the', 'measures', 'proposed', 'include'],
#  ['japanese', 'economy', 'the', 'measures', 'proposed', 'include', 'a'],
#  ['economy', 'the', 'measures', 'proposed', 'include', 'a', 'large'],
#  ['the', 'measures', 'proposed', 'include', 'a', 'large', 'supplementary'],
#  ['measures', 'proposed', 'include', 'a', 'large', 'supplementary', 'budget'],
#  ['proposed', 'include', 'a', 'large', 'supplementary', 'budget', 'and'],
#  ['include', 'a', 'large', 'supplementary', 'budget', 'and', 'record'],
#  ['a', 'large', 'supplementary', 'budget', 'and', 'record', 'public'],
#  ['large', 'supplementary', 'budget', 'and', 'record', 'public', 'works'],
#  ['supplementary', 'budget', 'and', 'record', 'public', 'works', 'spending'],
#  ['budget', 'and', 'record', 'public', 'works', 'spending', 'in'],
#  ['and', 'record', 'public', 'works', 'spending', 'in', 'the'],
#  ['record', 'public', 'works', 'spending', 'in', 'the', 'first'],
#  ['public', 'works', 'spending', 'in', 'the', 'first', 'half'],
#  ['works', 'spending', 'in', 'the', 'first', 'half', 'of'],
#  ['spending', 'in', 'the', 'first', 'half', 'of', 'the'],
#  ['in', 'the', 'first', 'half', 'of', 'the', 'financial'],
#  ['the', 'first', 'half', 'of', 'the', 'financial', 'year'],
#  ['first', 'half', 'of', 'the', 'financial', 'year', 'they'],
#  ['half', 'of', 'the', 'financial', 'year', 'they', 'also'],
#  ['of', 'the', 'financial', 'year', 'they', 'also', 'call'],
#  ['the', 'financial', 'year', 'they', 'also', 'call', 'for'],
#  ['financial', 'year', 'they', 'also', 'call', 'for', 'stepped'],
#  ['year', 'they', 'also', 'call', 'for', 'stepped', 'up'],
#  ['they', 'also', 'call', 'for', 'stepped', 'up', 'spending'],
#  ['also', 'call', 'for', 'stepped', 'up', 'spending', 'as'],
#  ['call', 'for', 'stepped', 'up', 'spending', 'as', 'an'],
#  ['for', 'stepped', 'up', 'spending', 'as', 'an', 'emergency'],
#  ['stepped', 'up', 'spending', 'as', 'an', 'emergency', 'measure'],
#  ['up', 'spending', 'as', 'an', 'emergency', 'measure', 'to'],
#  ['spending', 'as', 'an', 'emergency', 'measure', 'to', 'stimulate'],
#  ['as', 'an', 'emergency', 'measure', 'to', 'stimulate', 'the'],
#  ['an', 'emergency', 'measure', 'to', 'stimulate', 'the', 'economy'],
#  ['emergency', 'measure', 'to', 'stimulate', 'the', 'economy', 'despite'],
#  ['measure', 'to', 'stimulate', 'the', 'economy', 'despite', 'prime'],
#  ['to', 'stimulate', 'the', 'economy', 'despite', 'prime', 'minister'],
#  ['stimulate', 'the', 'economy', 'despite', 'prime', 'minister', 'yasuhiro'],
#  ['the', 'economy', 'despite', 'prime', 'minister', 'yasuhiro', 'nakasone'],
#  ['economy', 'despite', 'prime', 'minister', 'yasuhiro', 'nakasone', 's'],
#  ['despite', 'prime', 'minister', 'yasuhiro', 'nakasone', 's', 'avowed'],
#  ['prime', 'minister', 'yasuhiro', 'nakasone', 's', 'avowed', 'fiscal'],
#  ['minister', 'yasuhiro', 'nakasone', 's', 'avowed', 'fiscal', 'reform'],
#  ['yasuhiro', 'nakasone', 's', 'avowed', 'fiscal', 'reform', 'program'],
#  ['nakasone', 's', 'avowed', 'fiscal', 'reform', 'program', 'deputy'],
#  ['s', 'avowed', 'fiscal', 'reform', 'program', 'deputy', 'u'],
#  ['avowed', 'fiscal', 'reform', 'program', 'deputy', 'u', 's'],
#  ['fiscal', 'reform', 'program', 'deputy', 'u', 's', 'trade'],
#  ['reform', 'program', 'deputy', 'u', 's', 'trade', 'representative'],
#  ['program', 'deputy', 'u', 's', 'trade', 'representative', 'michael'],
#  ['deputy', 'u', 's', 'trade', 'representative', 'michael', 'smith'],
#  ['u', 's', 'trade', 'representative', 'michael', 'smith', 'and'],
#  ['s', 'trade', 'representative', 'michael', 'smith', 'and', 'makoto'],
#  ['trade', 'representative', 'michael', 'smith', 'and', 'makoto', 'kuroda'],
#  ['representative', 'michael', 'smith', 'and', 'makoto', 'kuroda', 'japan'],
#  ['michael', 'smith', 'and', 'makoto', 'kuroda', 'japan', 's'],
#  ['smith', 'and', 'makoto', 'kuroda', 'japan', 's', 'deputy'],
#  ['and', 'makoto', 'kuroda', 'japan', 's', 'deputy', 'minister'],
#  ['makoto', 'kuroda', 'japan', 's', 'deputy', 'minister', 'of'],
#  ['kuroda', 'japan', 's', 'deputy', 'minister', 'of', 'international'],
#  ['japan', 's', 'deputy', 'minister', 'of', 'international', 'trade'],
#  ['s', 'deputy', 'minister', 'of', 'international', 'trade', 'and'],
#  ['deputy', 'minister', 'of', 'international', 'trade', 'and', 'industry'],
#  ['minister', 'of', 'international', 'trade', 'and', 'industry', 'miti'],
#  ['of', 'international', 'trade', 'and', 'industry', 'miti', 'are'],
#  ['international', 'trade', 'and', 'industry', 'miti', 'are', 'due'],
#  ['trade', 'and', 'industry', 'miti', 'are', 'due', 'to'],
#  ['and', 'industry', 'miti', 'are', 'due', 'to', 'meet'],
#  ['industry', 'miti', 'are', 'due', 'to', 'meet', 'in'],
#  ['miti', 'are', 'due', 'to', 'meet', 'in', 'washington'],
#  ['are', 'due', 'to', 'meet', 'in', 'washington', 'this'],
#  ['due', 'to', 'meet', 'in', 'washington', 'this', 'week'],
#  ['to', 'meet', 'in', 'washington', 'this', 'week', 'in'],
#  ['meet', 'in', 'washington', 'this', 'week', 'in', 'an'],
#  ['in', 'washington', 'this', 'week', 'in', 'an', 'effort'],
#  ['washington', 'this', 'week', 'in', 'an', 'effort', 'to'],
#  ['this', 'week', 'in', 'an', 'effort', 'to', 'end'],
#  ['week', 'in', 'an', 'effort', 'to', 'end', 'the'],
#  ['in', 'an', 'effort', 'to', 'end', 'the', 'dispute'],
#  ['an', 'effort', 'to', 'end', 'the', 'dispute', 'china'],
#  ['effort', 'to', 'end', 'the', 'dispute', 'china', 'daily'],
#  ['to', 'end', 'the', 'dispute', 'china', 'daily', 'says'],
#  ['end', 'the', 'dispute', 'china', 'daily', 'says', 'vermin'],
# ...
#  ['grain', 'stocks', 'a', 'survey', 'of', 'provinces', 'and'],
#  ['stocks', 'a', 'survey', 'of', 'provinces', 'and', 'seven'],
#  ['a', 'survey', 'of', 'provinces', 'and', 'seven', 'cities'],
#  ['survey', 'of', 'provinces', 'and', 'seven', 'cities', 'showed'],
#  ['of', 'provinces', 'and', 'seven', 'cities', 'showed', 'vermin'],
#  ['provinces', 'and', 'seven', 'cities', 'showed', 'vermin', 'consume'],
#  ['and', 'seven', 'cities', 'showed', 'vermin', 'consume', 'between'],
#  ['seven', 'cities', 'showed', 'vermin', 'consume', 'between', 'seven'],
#  ['cities', 'showed', 'vermin', 'consume', 'between', 'seven', 'and'],
#  ['showed', 'vermin', 'consume', 'between', 'seven', 'and', 'pct'],
#  ['vermin', 'consume', 'between', 'seven', 'and', 'pct', 'of'],
#  ['consume', 'between', 'seven', 'and', 'pct', 'of', 'china'],
#  ['between', 'seven', 'and', 'pct', 'of', 'china', 's'],
#  ['seven', 'and', 'pct', 'of', 'china', 's', 'grain'],
#  ['and', 'pct', 'of', 'china', 's', 'grain', 'stocks'],
#  ['pct', 'of', 'china', 's', 'grain', 'stocks', 'the'],
#  ['of', 'china', 's', 'grain', 'stocks', 'the', 'china'],
#  ['china', 's', 'grain', 'stocks', 'the', 'china', 'daily'],
#  ['s', 'grain', 'stocks', 'the', 'china', 'daily', 'said'],
#  ['grain', 'stocks', 'the', 'china', 'daily', 'said', 'it'],
#  ['stocks', 'the', 'china', 'daily', 'said', 'it', 'also'],
#  ['the', 'china', 'daily', 'said', 'it', 'also', 'said'],
#  ['china', 'daily', 'said', 'it', 'also', 'said', 'that'],
#  ['daily', 'said', 'it', 'also', 'said', 'that', 'each'],
#  ['said', 'it', 'also', 'said', 'that', 'each', 'year'],
#  ['it', 'also', 'said', 'that', 'each', 'year', 'mln'],
#  ['also', 'said', 'that', 'each', 'year', 'mln', 'tonnes'],
#  ['said', 'that', 'each', 'year', 'mln', 'tonnes', 'or'],
#  ['that', 'each', 'year', 'mln', 'tonnes', 'or', 'pct'],
#  ['each', 'year', 'mln', 'tonnes', 'or', 'pct', 'of'],
#  ['year', 'mln', 'tonnes', 'or', 'pct', 'of', 'china'],
#  ['mln', 'tonnes', 'or', 'pct', 'of', 'china', 's'],
#  ['tonnes', 'or', 'pct', 'of', 'china', 's', 'fruit'],
#  ['or', 'pct', 'of', 'china', 's', 'fruit', 'output'],
#  ['pct', 'of', 'china', 's', 'fruit', 'output', 'are'],
#  ['of', 'china', 's', 'fruit', 'output', 'are', 'left'],
#  ['china', 's', 'fruit', 'output', 'are', 'left', 'to'],
#  ['s', 'fruit', 'output', 'are', 'left', 'to', 'rot'],
#  ['fruit', 'output', 'are', 'left', 'to', 'rot', 'and'],
#  ['output', 'are', 'left', 'to', 'rot', 'and', 'mln'],
#  ['are', 'left', 'to', 'rot', 'and', 'mln', 'tonnes'],
#  ['left', 'to', 'rot', 'and', 'mln', 'tonnes', 'or'],
#  ['to', 'rot', 'and', 'mln', 'tonnes', 'or', 'up'],
#  ['rot', 'and', 'mln', 'tonnes', 'or', 'up', 'to'],
#  ['and', 'mln', 'tonnes', 'or', 'up', 'to', 'pct'],
#  ['mln', 'tonnes', 'or', 'up', 'to', 'pct', 'of'],
#  ['tonnes', 'or', 'up', 'to', 'pct', 'of', 'its'],
#  ['or', 'up', 'to', 'pct', 'of', 'its', 'vegetables'],
#  ['up', 'to', 'pct', 'of', 'its', 'vegetables', 'the'],
#  ['to', 'pct', 'of', 'its', 'vegetables', 'the', 'paper'],
#  ['pct', 'of', 'its', 'vegetables', 'the', 'paper', 'blamed'],
#  ['of', 'its', 'vegetables', 'the', 'paper', 'blamed', 'the'],
#  ['its', 'vegetables', 'the', 'paper', 'blamed', 'the', 'waste'],
#  ['vegetables', 'the', 'paper', 'blamed', 'the', 'waste', 'on'],
#  ['the', 'paper', 'blamed', 'the', 'waste', 'on', 'inadequate'],
#  ['paper', 'blamed', 'the', 'waste', 'on', 'inadequate', 'storage'],
#  ['blamed', 'the', 'waste', 'on', 'inadequate', 'storage', 'and'],
#  ['the', 'waste', 'on', 'inadequate', 'storage', 'and', 'bad'],
#  ['waste', 'on', 'inadequate', 'storage', 'and', 'bad', 'preservation'],
#  ['on', 'inadequate', 'storage', 'and', 'bad', 'preservation', 'methods'],
#  ['inadequate', 'storage', 'and', 'bad', 'preservation', 'methods', 'it'],
#  ['storage', 'and', 'bad', 'preservation', 'methods', 'it', 'said'],
#  ['and', 'bad', 'preservation', 'methods', 'it', 'said', 'the'],
#  ['bad', 'preservation', 'methods', 'it', 'said', 'the', 'government'],
#  ['preservation', 'methods', 'it', 'said', 'the', 'government', 'had'],
#  ['methods', 'it', 'said', 'the', 'government', 'had', 'launched'],
#  ['it', 'said', 'the', 'government', 'had', 'launched', 'a'],
#  ['said', 'the', 'government', 'had', 'launched', 'a', 'national'],
#  ['the', 'government', 'had', 'launched', 'a', 'national', 'programme'],
#  ['government', 'had', 'launched', 'a', 'national', 'programme', 'to'],
#  ['had', 'launched', 'a', 'national', 'programme', 'to', 'reduce'],
#  ['launched', 'a', 'national', 'programme', 'to', 'reduce', 'waste'],
#  ['a', 'national', 'programme', 'to', 'reduce', 'waste', 'calling'],
#  ['national', 'programme', 'to', 'reduce', 'waste', 'calling', 'for'],
#  ['programme', 'to', 'reduce', 'waste', 'calling', 'for', 'improved'],
#  ['to', 'reduce', 'waste', 'calling', 'for', 'improved', 'technology'],
#  ['reduce', 'waste', 'calling', 'for', 'improved', 'technology', 'in'],
#  ['waste', 'calling', 'for', 'improved', 'technology', 'in', 'storage'],
#  ['calling', 'for', 'improved', 'technology', 'in', 'storage', 'and'],
#  ['for', 'improved', 'technology', 'in', 'storage', 'and', 'preservation'],
#  ['improved', 'technology', 'in', 'storage', 'and', 'preservation', 'and'],
#  ['technology', 'in', 'storage', 'and', 'preservation', 'and', 'greater'],
#  ['in', 'storage', 'and', 'preservation', 'and', 'greater', 'production'],
#  ['storage', 'and', 'preservation', 'and', 'greater', 'production', 'of'],
#  ['and', 'preservation', 'and', 'greater', 'production', 'of', 'additives'],
#  ['preservation', 'and', 'greater', 'production', 'of', 'additives', 'the'],
#  ['and', 'greater', 'production', 'of', 'additives', 'the', 'paper'],
#  ['greater', 'production', 'of', 'additives', 'the', 'paper', 'gave'],
#  ['production', 'of', 'additives', 'the', 'paper', 'gave', 'no'],
#  ['of', 'additives', 'the', 'paper', 'gave', 'no', 'further'],
#  ['additives', 'the', 'paper', 'gave', 'no', 'further', 'details'],
#  ['the', 'paper', 'gave', 'no', 'further', 'details', 'japan'],
#  ['paper', 'gave', 'no', 'further', 'details', 'japan', 'to'],
#  ['gave', 'no', 'further', 'details', 'japan', 'to', 'revise'],
#  ['no', 'further', 'details', 'japan', 'to', 'revise', 'long'],
#  ['further', 'details', 'japan', 'to', 'revise', 'long', 'term'],
#  ['details', 'japan', 'to', 'revise', 'long', 'term', 'energy'],
#  ['japan', 'to', 'revise', 'long', 'term', 'energy', 'demand'],
#  ['to', 'revise', 'long', 'term', 'energy', 'demand', 'downwards'],
#  ['revise', 'long', 'term', 'energy', 'demand', 'downwards', 'the'],
#  ['long', 'term', 'energy', 'demand', 'downwards', 'the', 'ministry'],
#  ['term', 'energy', 'demand', 'downwards', 'the', 'ministry', 'of'],
#  ['energy', 'demand', 'downwards', 'the', 'ministry', 'of', 'international'],
#  ['demand', 'downwards', 'the', 'ministry', 'of', 'international', 'trade'],
#  ['downwards', 'the', 'ministry', 'of', 'international', 'trade', 'and'],
#  ['the', 'ministry', 'of', 'international', 'trade', 'and', 'industry'],
#  ['ministry', 'of', 'international', 'trade', 'and', 'industry', 'miti'],
#  ['of', 'international', 'trade', 'and', 'industry', 'miti', 'will'],
#  ['international', 'trade', 'and', 'industry', 'miti', 'will', 'revise'],
#  ['trade', 'and', 'industry', 'miti', 'will', 'revise', 'its'],
#  ['and', 'industry', 'miti', 'will', 'revise', 'its', 'long'],
#  ['industry', 'miti', 'will', 'revise', 'its', 'long', 'term'],
#  ['miti', 'will', 'revise', 'its', 'long', 'term', 'energy'],
#  ['will', 'revise', 'its', 'long', 'term', 'energy', 'supply'],
#  ['revise', 'its', 'long', 'term', 'energy', 'supply', 'demand'],
#  ['its', 'long', 'term', 'energy', 'supply', 'demand', 'outlook'],
#  ['long', 'term', 'energy', 'supply', 'demand', 'outlook', 'by'],
#  ['term', 'energy', 'supply', 'demand', 'outlook', 'by', 'august'],
#  ['energy', 'supply', 'demand', 'outlook', 'by', 'august', 'to'],
#  ['supply', 'demand', 'outlook', 'by', 'august', 'to', 'meet'],
#  ['demand', 'outlook', 'by', 'august', 'to', 'meet', 'a'],
#  ['outlook', 'by', 'august', 'to', 'meet', 'a', 'forecast'],
#  ['by', 'august', 'to', 'meet', 'a', 'forecast', 'downtrend'],
#  ['august', 'to', 'meet', 'a', 'forecast', 'downtrend', 'in'],
#  ['to', 'meet', 'a', 'forecast', 'downtrend', 'in', 'japanese'],
#  ['meet', 'a', 'forecast', 'downtrend', 'in', 'japanese', 'energy'],
#  ['a', 'forecast', 'downtrend', 'in', 'japanese', 'energy', 'demand'],
#  ['forecast', 'downtrend', 'in', 'japanese', 'energy', 'demand', 'ministry'],
#  ['downtrend', 'in', 'japanese', 'energy', 'demand', 'ministry', 'officials'],
#  ['in', 'japanese', 'energy', 'demand', 'ministry', 'officials', 'said'],
#  ['japanese', 'energy', 'demand', 'ministry', 'officials', 'said', 'miti'],
#  ['energy', 'demand', 'ministry', 'officials', 'said', 'miti', 'is'],
#  ['demand', 'ministry', 'officials', 'said', 'miti', 'is', 'expected'],
#  ['ministry', 'officials', 'said', 'miti', 'is', 'expected', 'to'],
#  ['officials', 'said', 'miti', 'is', 'expected', 'to', 'lower'],
#  ['said', 'miti', 'is', 'expected', 'to', 'lower', 'the'],
#  ['miti', 'is', 'expected', 'to', 'lower', 'the', 'projection'],
#  ['is', 'expected', 'to', 'lower', 'the', 'projection', 'for'],
#  ['expected', 'to', 'lower', 'the', 'projection', 'for', 'primary'],
#  ['to', 'lower', 'the', 'projection', 'for', 'primary', 'energy'],
#  ['lower', 'the', 'projection', 'for', 'primary', 'energy', 'supplies'],
#  ['the', 'projection', 'for', 'primary', 'energy', 'supplies', 'in'],
#  ['projection', 'for', 'primary', 'energy', 'supplies', 'in', 'the'],
#  ['for', 'primary', 'energy', 'supplies', 'in', 'the', 'year'],
#  ['primary', 'energy', 'supplies', 'in', 'the', 'year', 'to'],
#  ['energy', 'supplies', 'in', 'the', 'year', 'to', 'mln'],
#  ['supplies', 'in', 'the', 'year', 'to', 'mln', 'kilolitres'],
#  ['in', 'the', 'year', 'to', 'mln', 'kilolitres', 'kl'],
#  ['the', 'year', 'to', 'mln', 'kilolitres', 'kl', 'from'],
#  ['year', 'to', 'mln', 'kilolitres', 'kl', 'from', 'mln'],
#  ['to', 'mln', 'kilolitres', 'kl', 'from', 'mln', 'they'],
#  ['mln', 'kilolitres', 'kl', 'from', 'mln', 'they', 'said'],
#  ['kilolitres', 'kl', 'from', 'mln', 'they', 'said', 'the'],
#  ['kl', 'from', 'mln', 'they', 'said', 'the', 'decision'],
#  ['from', 'mln', 'they', 'said', 'the', 'decision', 'follows'],
#  ['mln', 'they', 'said', 'the', 'decision', 'follows', 'the'],
#  ['they', 'said', 'the', 'decision', 'follows', 'the', 'emergence'],
#  ['said', 'the', 'decision', 'follows', 'the', 'emergence', 'of'],
#  ['the', 'decision', 'follows', 'the', 'emergence', 'of', 'structural'],
#  ['decision', 'follows', 'the', 'emergence', 'of', 'structural', 'changes'],
#  ['follows', 'the', 'emergence', 'of', 'structural', 'changes', 'in'],
#  ['the', 'emergence', 'of', 'structural', 'changes', 'in', 'japanese'],
#  ['emergence', 'of', 'structural', 'changes', 'in', 'japanese', 'industry'],
#  ['of', 'structural', 'changes', 'in', 'japanese', 'industry', 'following'],
#  ['structural', 'changes', 'in', 'japanese', 'industry', 'following', 'the'],
#  ['changes', 'in', 'japanese', 'industry', 'following', 'the', 'rise'],
#  ['in', 'japanese', 'industry', 'following', 'the', 'rise', 'in'],
#  ['japanese', 'industry', 'following', 'the', 'rise', 'in', 'the'],
#  ['industry', 'following', 'the', 'rise', 'in', 'the', 'value'],
#  ['following', 'the', 'rise', 'in', 'the', 'value', 'of'],
#  ['the', 'rise', 'in', 'the', 'value', 'of', 'the'],
#  ['rise', 'in', 'the', 'value', 'of', 'the', 'yen'],
#  ['in', 'the', 'value', 'of', 'the', 'yen', 'and'],
#  ['the', 'value', 'of', 'the', 'yen', 'and', 'a'],
#  ['value', 'of', 'the', 'yen', 'and', 'a', 'decline'],
#  ['of', 'the', 'yen', 'and', 'a', 'decline', 'in'],
#  ['the', 'yen', 'and', 'a', 'decline', 'in', 'domestic'],
#  ['yen', 'and', 'a', 'decline', 'in', 'domestic', 'electric'],
#  ['and', 'a', 'decline', 'in', 'domestic', 'electric', 'power'],
#  ['a', 'decline', 'in', 'domestic', 'electric', 'power', 'demand'],
#  ['decline', 'in', 'domestic', 'electric', 'power', 'demand', 'miti'],
#  ['in', 'domestic', 'electric', 'power', 'demand', 'miti', 'is'],
#  ['domestic', 'electric', 'power', 'demand', 'miti', 'is', 'planning'],
#  ['electric', 'power', 'demand', 'miti', 'is', 'planning', 'to'],
#  ['power', 'demand', 'miti', 'is', 'planning', 'to', 'work'],
#  ['demand', 'miti', 'is', 'planning', 'to', 'work', 'out'],
#  ['miti', 'is', 'planning', 'to', 'work', 'out', 'a'],
#  ['is', 'planning', 'to', 'work', 'out', 'a', 'revised'],
#  ['planning', 'to', 'work', 'out', 'a', 'revised', 'energy'],
#  ['to', 'work', 'out', 'a', 'revised', 'energy', 'supply'],
#  ['work', 'out', 'a', 'revised', 'energy', 'supply', 'demand'],
#  ['out', 'a', 'revised', 'energy', 'supply', 'demand', 'outlook'],
#  ['a', 'revised', 'energy', 'supply', 'demand', 'outlook', 'through'],
#  ['revised',
#   'energy',
#   'supply',
#   'demand',
#   'outlook',
#   'through',
#   'deliberations'],
#  ['energy', 'supply', 'demand', 'outlook', 'through', 'deliberations', 'of'],
#  ['supply',
#   'demand',
#   'outlook',
#   'through',
#   'deliberations',
#   'of',
#   'committee'],
#  ['demand',
#   'outlook',
#   'through',
#   'deliberations',
#   'of',
#   'committee',
#   'meetings'],
#  ['outlook', 'through', 'deliberations', 'of', 'committee', 'meetings', 'of'],
#  ['through', 'deliberations', 'of', 'committee', 'meetings', 'of', 'the'],
#  ['deliberations', 'of', 'committee', 'meetings', 'of', 'the', 'agency'],
#  ['of', 'committee', 'meetings', 'of', 'the', 'agency', 'of'],
#  ['committee', 'meetings', 'of', 'the', 'agency', 'of', 'natural'],
#  ['meetings', 'of', 'the', 'agency', 'of', 'natural', 'resources'],
#  ['of', 'the', 'agency', 'of', 'natural', 'resources', 'and'],
#  ['the', 'agency', 'of', 'natural', 'resources', 'and', 'energy'],
#  ['agency', 'of', 'natural', 'resources', 'and', 'energy', 'the'],
#  ['of', 'natural', 'resources', 'and', 'energy', 'the', 'officials'],
#  ['natural', 'resources', 'and', 'energy', 'the', 'officials', 'said'],
#  ['resources', 'and', 'energy', 'the', 'officials', 'said', 'they'],
#  ['and', 'energy', 'the', 'officials', 'said', 'they', 'said'],
#  ['energy', 'the', 'officials', 'said', 'they', 'said', 'miti'],
#  ['the', 'officials', 'said', 'they', 'said', 'miti', 'will'],
#  ['officials', 'said', 'they', 'said', 'miti', 'will', 'also'],
#  ['said', 'they', 'said', 'miti', 'will', 'also', 'review'],
#  ['they', 'said', 'miti', 'will', 'also', 'review', 'the'],
#  ['said', 'miti', 'will', 'also', 'review', 'the', 'breakdown'],
#  ['miti', 'will', 'also', 'review', 'the', 'breakdown', 'of'],
#  ['will', 'also', 'review', 'the', 'breakdown', 'of', 'energy'],
#  ['also', 'review', 'the', 'breakdown', 'of', 'energy', 'supply'],
#  ['review', 'the', 'breakdown', 'of', 'energy', 'supply', 'sources'],
#  ['the', 'breakdown', 'of', 'energy', 'supply', 'sources', 'including'],
#  ['breakdown', 'of', 'energy', 'supply', 'sources', 'including', 'oil'],
#  ['of', 'energy', 'supply', 'sources', 'including', 'oil', 'nuclear'],
#  ['energy', 'supply', 'sources', 'including', 'oil', 'nuclear', 'coal'],
#  ['supply', 'sources', 'including', 'oil', 'nuclear', 'coal', 'and'],
#  ['sources', 'including', 'oil', 'nuclear', 'coal', 'and', 'natural'],
#  ['including', 'oil', 'nuclear', 'coal', 'and', 'natural', 'gas'],
#  ['oil', 'nuclear', 'coal', 'and', 'natural', 'gas', 'nuclear'],
#  ['nuclear', 'coal', 'and', 'natural', 'gas', 'nuclear', 'energy'],
#  ['coal', 'and', 'natural', 'gas', 'nuclear', 'energy', 'provided'],
#  ['and', 'natural', 'gas', 'nuclear', 'energy', 'provided', 'the'],
#  ['natural', 'gas', 'nuclear', 'energy', 'provided', 'the', 'bulk'],
#  ['gas', 'nuclear', 'energy', 'provided', 'the', 'bulk', 'of'],
#  ['nuclear', 'energy', 'provided', 'the', 'bulk', 'of', 'japan'],
#  ['energy', 'provided', 'the', 'bulk', 'of', 'japan', 's'],
#  ['provided', 'the', 'bulk', 'of', 'japan', 's', 'electric'],
#  ['the', 'bulk', 'of', 'japan', 's', 'electric', 'power'],
#  ['bulk', 'of', 'japan', 's', 'electric', 'power', 'in'],
#  ['of', 'japan', 's', 'electric', 'power', 'in', 'the'],
#  ['japan', 's', 'electric', 'power', 'in', 'the', 'fiscal'],
#  ['s', 'electric', 'power', 'in', 'the', 'fiscal', 'year'],
#  ['electric', 'power', 'in', 'the', 'fiscal', 'year', 'ended'],
#  ['power', 'in', 'the', 'fiscal', 'year', 'ended', 'march'],
#  ...]

# %% [markdown]
# # Create Function for the Frequency

# %%
def frequency(n, text):
    n_grams = list(ngrams(text, n))
    fdist = FreqDist(n_grams)
    return fdist

# %% [markdown]
# To calculate the frequency of the n grams, we split the text into n grams and use the FreqDist() function.

# %%
# Calculate exemplary frequency for n = 2
frequency(3, corpus)
# Out:
# FreqDist({('mln', 'vs', 'mln'): 3402, ('the', 'u', 's'): 2105, ('cts', 'vs', 'cts'): 1779, ('revs', 'mln', 'vs'): 1515, ('shr', 'cts', 'vs'): 1446, ('the', 'company', 'said'): 1180, ('vs', 'cts', 'net'): 1169, ('cts', 'net', 'vs'): 1082, ('of', 'mln', 'dlrs'): 1049, ('net', 'vs', 'revs'): 887, ...})
